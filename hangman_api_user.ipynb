# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
from keras.models import load_model
from string import ascii_lowercase 
import numpy as np
np.random.seed(6)
from keras_self_attention import SeqSelfAttention

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %% [markdown]
# # Training

# %% [markdown]
# This code block involves model training and saving

# %%
import random
import string
import time
import re
import collections
import numpy as np
from keras.layers import *
from keras.models import Model, load_model
from keras import optimizers, backend as K
from keras_self_attention import SeqSelfAttention
from string import ascii_lowercase 
np.random.seed(6)
import time

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
#         self.hangman_url = self.determine_hangman_url()
#         self.access_token = access_token
#         self.session = session or requests.Session()
#         self.timeout = timeout
        self.guessed_letters = []
        self.train_dictionary= []
        self.test_dictionary = []
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.train_dictionary)).most_common()
        self.maxLen = max(len(w) for w in self.train_dictionary)
        self.encoderDict=dict(zip(ascii_lowercase, range(26)))
        self.encoderDict["_"]=26 #missing letters
        self.encoderDict["."] =27 #padding
        self.decoderDict=dict(zip(range(26),ascii_lowercase))
        self.numTries=6
        self.outputs=[]
        self.inputs1=[]
        self.inputs2=[]
        self.remainingLetters=[]
        self.model=self.createModel(self.maxLen)
        print(self.model.summary())
        print()
        
        self.correctGuesses=0
        self.totalGuesses=0
        self.numWins=0
        self.totalGames=0
        
        self.model.compile(loss = 'categorical_crossentropy', optimizer = optimizers.Adam(6e-4))
        #self.train()
        self.current_dictionary = []
        
#     @staticmethod
#     def determine_hangman_url():
#         links = ['https://trexsim.com', 'https://sg.trexsim.com']

#         data = {link: 0 for link in links}

#         for link in links:

#             requests.get(link)

#             for i in range(10):
#                 s = time.time()
#                 requests.get(link)
#                 data[link] = time.time() - s

#         link = sorted(data.items(), key=lambda x: x[1])[0][0]
#         link += '/trexsim/hangman'
#         return link
    def createModel(self,n=30):
        #5e-4
        
        inputPath1=Input(shape=(n,28,), name='path1')
        inputPath2=Input(shape=(26,), name='path2')
        #     path1=Embedding(n,100, mask_zero = True)(inputPath1)
        #     p1=Embedding(30,100, mask_zero = True)(p1)
        path1=Bidirectional(LSTM(256,return_sequences=True))(inputPath1)
        path1=SeqSelfAttention(attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,attention_activation='relu')(path1)
        path1=TimeDistributed(Dense(64,activation='gelu', kernel_initializer='uniform'))(path1)
        path1=Bidirectional(LSTM(256))(path1)
        #path2=SeqSelfAttention(attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,attention_activation='sigmoid')(path2)
        path1=Dense(256,activation='gelu', kernel_initializer='uniform')(path1)

        path2=Dense(128,activation='gelu', kernel_initializer='uniform')(inputPath2)
        path2=Dense(128,activation='gelu', kernel_initializer='uniform')(path2)
        merged = Concatenate()([path2, path1])
        merged = Dense(256,activation='gelu', kernel_initializer='uniform')(merged)
#         merged = Dense(256,activation='tanh', kernel_initializer='uniform')(merged)
        merged = Dense(26,activation='softmax', kernel_initializer='uniform')(merged)
        return Model(inputs=[inputPath1,inputPath2], outputs=merged, name='model')
    
    
    def reset(self, word):
        self.numTries=6
        self.outputs=[]
        self.inputs1=[]
        self.inputs2=[]
        self.guessed_letters=[]
        self.remainingLetters=dict(collections.Counter(word))
        
        
    def encode(self,word):
        if(len(word)<self.maxLen):word=word+"".join(["."]*(self.maxLen-len(word)))
        encoded=np.zeros((1,self.maxLen,28))
        for i in range(self.maxLen):
            if(word[i]=="." or word[i] in self.guessed_letters):
                    encoded[0,i,self.encoderDict[word[i]]]=1
            else:encoded[0,i,26]=1
        return encoded    
    def play(self,word):
        self.reset(word)
        
        while sum(self.remainingLetters.values())>0 and self.numTries>0:
            i1=self.encode(word)
            i2=np.zeros((1,26))
            for x in self.guessed_letters:
                i2[0,self.encoderDict[x]]=1
            output = np.zeros((1,26))
            for k,v in self.remainingLetters.items():
                output[0,self.encoderDict[k]] = v
            output[0]/=output[0].sum() 
            #print(i1.shape,i2.shape,output.shape)
            if len(self.inputs1)==0:
                self.inputs1,self.inputs2,self.outputs=i1,i2,output
            else:
#                 print(i1.shape,i2.shape,output.shape)
#                 print(self.inputs1.shape,self.inputs2.shape,self.outputs.shape)
                self.inputs1=np.append(self.inputs1,i1,axis=0)
                self.inputs2=np.append(self.inputs2,i2,axis=0)
                self.outputs=np.append(self.outputs,output,axis=0)
                
            guesses = np.flip(np.argsort(self.model.predict([i1,i2],verbose=None)))[0]
            #print(guesses)
            for i in guesses.tolist():
                guess = self.decoderDict[i]
                if guess not in self.guessed_letters:
                    self.guessed_letters.append(guess)
                    break
#             print(word,guess,self.remainingLetters)
#             print()
#             print(output)
#             print()
            self.totalGuesses+=1
            if guess in self.remainingLetters and self.remainingLetters[guess]>0:
                self.remainingLetters[guess]=0
                self.correctGuesses+=1
            else: self.numTries-=1  
 
        if(sum(self.remainingLetters.values())==0):
            self.numWins+=1
        self.totalGames+=1        
        return(self.inputs1,self.inputs2,self.outputs)
    
            
    def train(self):
        
        wordBatchSize=250
        epochs=1
        xTrain1=0
        xTrain2=0
        yTrain=0
        batchNum=0
        totalBatches = (len(self.train_dictionary)//wordBatchSize+1)
        for e in range(epochs):
            count=0
            t1=time.time()
            for word in self.train_dictionary:
                count+=1 
                input1, input2, output = self.play(word)
                if(count==1):
                    xTrain1=input1
                    xTrain2=input2
                    yTrain=output
                else:
#                     print(xTrain1.shape,xTrain2.shape,yTrain.shape)
#                     print(input1.shape,input2.shape,output.shape)
                    xTrain1=np.append(xTrain1,input1,axis=0)
                    xTrain2=np.append(xTrain2,input2,axis=0)
                    yTrain=np.append(yTrain,output,axis=0)
                if(count==wordBatchSize):
                    batchNum+=1
                    count=0
                    ##train function
                    print("Starting training for Batch: "+str(batchNum) +" /"+str(totalBatches)+" and Epoch: "+ str(e+1))
                    print(xTrain1.shape,xTrain2.shape,yTrain.shape)
                    self.model.fit([xTrain1,xTrain2],yTrain,batch_size=256)
                    print("Time taken in seconds to train the batch: "+str(time.time()-t1))
                    print("Correct Guesses: "+str(self.correctGuesses)+"/"+str(self.totalGuesses)+" , number of wins: "+
                         str(self.numWins)+"/"+str(self.totalGames))
                    t1=time.time()
                    
                    self.correctGuesses=0
                    self.totalGuesses=0
                    self.numWins=0
                    self.totalGames=0
                    xTrain1=0
                    xTrain2=0
                    yTrain=0
            count=0
            ##train function
            print("Completing training for Epoch: "+str(e+1))
#             self.model.fit([xTrain1,xTrain2],yTrain,batch_size=256)
#             xTrain1=0
#             xTrain2=0
#             yTrain=0
                    
    def trainOnTest(self):
        
        wordBatchSize=250
        epochs=1
        xTrain1=0
        xTrain2=0
        yTrain=0
        batchNum=0
        totalBatches = (len(self.test_dictionary)//wordBatchSize+1)
        for e in range(epochs):
            count=0
            t1=time.time()
            for word in self.test_dictionary:
                count+=1
                input1, input2, output = self.play(word)
                if(count==1):
                    xTrain1=input1
                    xTrain2=input2
                    yTrain=output
                else:
#                     print(xTrain1.shape,xTrain2.shape,yTrain.shape)
#                     print(input1.shape,input2.shape,output.shape)
                    xTrain1=np.append(xTrain1,input1,axis=0)
                    xTrain2=np.append(xTrain2,input2,axis=0)
                    yTrain=np.append(yTrain,output,axis=0)
                if(count==wordBatchSize):
                    batchNum+=1
                    count=0
                    ##train function
                    print("Starting training for Batch: "+str(batchNum) +" /"+str(totalBatches)+" and Epoch: "+ str(e+1))
                    print(xTrain1.shape,xTrain2.shape,yTrain.shape)
                    self.model.fit([xTrain1,xTrain2],yTrain,batch_size=256)
                    print("Time taken in seconds to train the batch: "+str(time.time()-t1))
                    print("Correct Guesses: "+str(self.correctGuesses)+"/"+str(self.totalGuesses)+" , number of wins: "+
                         str(self.numWins)+"/"+str(self.totalGames))
                    t1=time.time()
                    
                    self.correctGuesses=0
                    self.totalGuesses=0
                    self.numWins=0
                    self.totalGames=0
                    xTrain1=0
                    xTrain2=0
                    yTrain=0
            count=0
            ##train function
            print("Completing training for Epoch: "+str(e+1))
#             self.model.fit([xTrain1,xTrain2],yTrain,batch_size=256)
#             xTrain1=0
#             xTrain2=0
#             yTrain=0
    def loadModel(self,modelPath):
        self.model=load_model(modelPath)
    def test(self):
        t1=time.time()
        self.correctGuesses=0
        self.totalGuesses=0
        self.numWins=0
        self.totalGames=0
        for word in self.test_dictionary:
            self.play(word)
        print("Time taken in seconds to test the batch of "+str(len(self.test_dictionary)) +" words: "+str(time.time()-t1))
        print("Correct Guesses: "+str(self.correctGuesses)+"/"+str(self.totalGuesses)+" , number of wins: "+
             str(self.numWins)+"/"+str(self.totalGames))
        self.correctGuesses=0
        self.totalGuesses=0
        self.numWins=0
        self.totalGames=0



#             self.model.fit([xTrain1,xTrain2],yTrain,batch_size=256)
#             xTrain1=0
#             xTrain2=0
#             yTrain=0
                    
                                 
    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        word="".join(word)
        clean_word = word[::2].replace("_",".")
        
        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter
    def match(self,word1,word2):
        word1=list(word1)
        word2=list(word2)
        if(len(word1)==len(word2)):
            for x in range(len(word1)):
                if word2[x]!="_" and word2[x]!=word1[x]:
                    return False
            return True
        else: return False    
    def guess1(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        word="".join(word)    
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
                
            # if dictionary word is a possible match then add it to the current dictionary
            if self.match(dict_word,word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter

    def guess2(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        word="".join(word)
                
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
                
            # if dictionary word is a possible match then add it to the current dictionary
            if self.match(dict_word,word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        guess_letter = '!'
        d={}
        for x in range(len(word)):
            if word[x]=="_":
                sortedCount=collections.Counter("".join([a[x] for a in new_dictionary]))
                total = sum(sortedCount.values())
                sortedCount = {key:sortedCount[key]/total for key in sortedCount.keys()}
                sortedCount = sorted(sortedCount.items(), key=lambda x:-x[1])
                #print(sortedCount)
                d[x]=sortedCount
        maxProbalities = {}
        maxProb = 0 
        if(len(d)>0):
            for a in d.keys():
                for letter,prob in d[a]:
                    if letter not in self.guessed_letters:
                        if maxProb<prob:
                            maxProb = prob
                            guess_letter = letter
                            break
                        
#         # count occurrence of all characters in possible word matches
#         full_dict_string = "".join(new_dictionary)
        
#         c = collections.Counter(full_dict_string)
#         sorted_letter_count = c.most_common()                   
        
#         guess_letter = '!'
        
#         # return most frequently occurring letter in all possible words that hasn't been guessed yet
#         for letter,instance_count in sorted_letter_count:
#             if letter not in self.guessed_letters:
#                 guess_letter = letter
#                 break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter
    
    def guess3(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        word="".join(word)
                
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
                
            # if dictionary word is a possible match then add it to the current dictionary
            if self.match(dict_word,word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        guess_letter = '!'
        d={}
        for x in range(len(word)):
            totalProb = {}
            if word[x]=="_":
                sortedCount=collections.Counter("".join([a[x] for a in new_dictionary]))
                total = sum(sortedCount.values())
                sortedCount = {key:sortedCount[key]/total for key in sortedCount.keys()}
#                 sortedCount = sorted(sortedCount.items(), key=lambda x:-x[1])
                #print(sortedCount)
                d[x]=sortedCount
                totalProb = {x: totalProb.get(x, 0) + sortedCount.get(x, 0)
                    for x in set(totalProb).union(sortedCount)}
            d[-1]=sorted(totalProb.items(), key=lambda x:-x[1])   
        maxProbalities = {}
        maxProb = 0 
        if(len(d)>0):
            if(-1 in d):
                for letter,prob in d[-1]:
                    if letter not in self.guessed_letters:
                        if maxProb<prob:
                            maxProb = prob
                            guess_letter = letter
                            break
                
#             for a in d.keys():
#                 for letter,prob in d[a]:
#                     if letter not in self.guessed_letters:
#                         if maxProb<prob:
#                             maxProb = prob
#                             guess_letter = letter
#                             break
                        
#         # count occurrence of all characters in possible word matches
#         full_dict_string = "".join(new_dictionary)
        
#         c = collections.Counter(full_dict_string)
#         sorted_letter_count = c.most_common()                   
        
#         guess_letter = '!'
        
#         # return most frequently occurring letter in all possible words that hasn't been guessed yet
#         for letter,instance_count in sorted_letter_count:
#             if letter not in self.guessed_letters:
#                 guess_letter = letter
#                 break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter
    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = np.array(text_file.read().splitlines())
        np.random.shuffle(full_dictionary)
        numTrain = 210000
        self.train_dictionary= full_dictionary[:numTrain].tolist()
        self.test_dictionary = full_dictionary[numTrain:].tolist()
        text_file.close()
        return full_dictionary.tolist()
                
    def playGame(self, practice=True, verbose=True):
        
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        game_id=0
        successfulGames=0
        for word in self.test_dictionary:
            game_id+=1
            word = list(word)
            self.guessed_letters = []
            self.current_dictionary = self.train_dictionary
            tries_remains = 6
            p=1
            mask=np.random.choice(np.arange(2),len(word),p=[p,1-p])
            modifiedWord = [word[i] if mask[i]==1 else '_' for i in list(range(len(word)))]
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, "".join(modifiedWord)))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess3(modifiedWord)
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                a = [1 if (modifiedWord[i]=="_" and word[i]==guess_letter) else 0 for i in list(range(len(word)))]
                if(sum(a) == 0):tries_remains-=1
                else:
                    for x in range(len(word)):
                        if(a[x]==1):
                            modifiedWord[x] = word[x]
                status=""
                if(modifiedWord==word):status="success"
                elif(tries_remains==0):status="failed"
                else:status="ongoing"
                if status=="success":
                    successfulGames+=1
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    break
                elif status=="failed":
                    reason = "# of tries exceeded!"
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    break
                elif status=="ongoing":
                    if verbose:
                        print("Continuing game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, modifiedWord))
            
        print("Game finished with accuracy: {0}.".format(successfulGames/len(self.test_dictionary)))

# %%
api=HangmanAPI()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  path1 (InputLayer)             [(None, 29, 28)]     0           []
#
#  bidirectional (Bidirectional)  (None, 29, 512)      583680      ['path1[0][0]']
#
#  seq_self_attention (SeqSelfAtt  (None, 29, 512)     262145      ['bidirectional[0][0]']
#  ention)
#
#  path2 (InputLayer)             [(None, 26)]         0           []
#
#  time_distributed (TimeDistribu  (None, 29, 64)      32832       ['seq_self_attention[0][0]']
#  ted)
#
#  dense_2 (Dense)                (None, 128)          3456        ['path2[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 512)         657408      ['time_distributed[0][0]']
#  )
#
#  dense_3 (Dense)                (None, 128)          16512       ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['bidirectional_1[0][0]']
#
#  concatenate (Concatenate)      (None, 384)          0           ['dense_3[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_4 (Dense)                (None, 256)          98560       ['concatenate[0][0]']
#
#  dense_5 (Dense)                (None, 26)           6682        ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 1,792,603
# Trainable params: 1,792,603
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
api.train()
# Out:
# Starting training for Batch: 1 /841 and Epoch: 1
# (2724, 29, 28) (2724, 26) (2724, 26)
# 11/11 [==============================] - 9s 590ms/step - loss: 2.4835
# Time taken in seconds to train the batch: 98.99405217170715
# Correct Guesses: 1601/2724 , number of wins: 134/250
# Starting training for Batch: 2 /841 and Epoch: 1
# (2792, 29, 28) (2792, 26) (2792, 26)
# 11/11 [==============================] - 6s 550ms/step - loss: 2.4943
# Time taken in seconds to train the batch: 93.72159504890442
# Correct Guesses: 1629/2792 , number of wins: 125/250
# Starting training for Batch: 3 /841 and Epoch: 1
# (2792, 29, 28) (2792, 26) (2792, 26)
# 11/11 [==============================] - 6s 561ms/step - loss: 2.4798
# Time taken in seconds to train the batch: 93.08905053138733
# Correct Guesses: 1645/2792 , number of wins: 128/250
# Starting training for Batch: 4 /841 and Epoch: 1
# (2745, 29, 28) (2745, 26) (2745, 26)
# 11/11 [==============================] - 6s 553ms/step - loss: 2.5087
# Time taken in seconds to train the batch: 91.61823534965515
# Correct Guesses: 1615/2745 , number of wins: 121/250
# Starting training for Batch: 5 /841 and Epoch: 1
# (2757, 29, 28) (2757, 26) (2757, 26)
# 11/11 [==============================] - 6s 548ms/step - loss: 2.5070
# Time taken in seconds to train the batch: 92.0613899230957
# Correct Guesses: 1578/2757 , number of wins: 117/250
# Starting training for Batch: 6 /841 and Epoch: 1
# (2832, 29, 28) (2832, 26) (2832, 26)
# 12/12 [==============================] - 6s 525ms/step - loss: 2.4955
# Time taken in seconds to train the batch: 94.67463850975037
# Correct Guesses: 1670/2832 , number of wins: 120/250
# Starting training for Batch: 7 /841 and Epoch: 1
# (2747, 29, 28) (2747, 26) (2747, 26)
# 11/11 [==============================] - 6s 555ms/step - loss: 2.4842
# Time taken in seconds to train the batch: 91.78040742874146
# Correct Guesses: 1610/2747 , number of wins: 128/250
# Starting training for Batch: 8 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 6s 555ms/step - loss: 2.4656
# Time taken in seconds to train the batch: 90.89861297607422
# Correct Guesses: 1586/2721 , number of wins: 125/250
# Starting training for Batch: 9 /841 and Epoch: 1
# (2769, 29, 28) (2769, 26) (2769, 26)
# 11/11 [==============================] - 6s 552ms/step - loss: 2.5479
# Time taken in seconds to train the batch: 92.4345109462738
# Correct Guesses: 1631/2769 , number of wins: 120/250
# Starting training for Batch: 10 /841 and Epoch: 1
# (2787, 29, 28) (2787, 26) (2787, 26)
# 11/11 [==============================] - 6s 565ms/step - loss: 2.4827
# Time taken in seconds to train the batch: 93.20448398590088
# Correct Guesses: 1625/2787 , number of wins: 125/250
# Starting training for Batch: 11 /841 and Epoch: 1
# (2756, 29, 28) (2756, 26) (2756, 26)
# 11/11 [==============================] - 6s 556ms/step - loss: 2.4754
# Time taken in seconds to train the batch: 92.27797865867615
# Correct Guesses: 1603/2756 , number of wins: 119/250
# Starting training for Batch: 12 /841 and Epoch: 1
# (2755, 29, 28) (2755, 26) (2755, 26)
# 11/11 [==============================] - 6s 550ms/step - loss: 2.5016
# Time taken in seconds to train the batch: 92.08064556121826
# Correct Guesses: 1586/2755 , number of wins: 121/250
# Starting training for Batch: 13 /841 and Epoch: 1
# (2751, 29, 28) (2751, 26) (2751, 26)
# 11/11 [==============================] - 6s 558ms/step - loss: 2.5171
# Time taken in seconds to train the batch: 94.48374390602112
# Correct Guesses: 1562/2751 , number of wins: 111/250
# Starting training for Batch: 14 /841 and Epoch: 1
# (2778, 29, 28) (2778, 26) (2778, 26)
# 11/11 [==============================] - 6s 553ms/step - loss: 2.5184
# Time taken in seconds to train the batch: 92.78500580787659
# Correct Guesses: 1629/2778 , number of wins: 116/250
# Starting training for Batch: 15 /841 and Epoch: 1
# (2770, 29, 28) (2770, 26) (2770, 26)
# 11/11 [==============================] - 6s 553ms/step - loss: 2.5307
# Time taken in seconds to train the batch: 92.49827241897583
# Correct Guesses: 1608/2770 , number of wins: 119/250
# Starting training for Batch: 16 /841 and Epoch: 1
# (2761, 29, 28) (2761, 26) (2761, 26)
# 11/11 [==============================] - 6s 554ms/step - loss: 2.4983
# Time taken in seconds to train the batch: 92.33476710319519
# Correct Guesses: 1614/2761 , number of wins: 120/250
# Starting training for Batch: 17 /841 and Epoch: 1
# (2806, 29, 28) (2806, 26) (2806, 26)
# 11/11 [==============================] - 6s 555ms/step - loss: 2.4821
# Time taken in seconds to train the batch: 93.4867434501648
# Correct Guesses: 1689/2806 , number of wins: 133/250
# Starting training for Batch: 18 /841 and Epoch: 1
# (2763, 29, 28) (2763, 26) (2763, 26)
# 11/11 [==============================] - 6s 546ms/step - loss: 2.5082
# Time taken in seconds to train the batch: 92.27395391464233
# Correct Guesses: 1611/2763 , number of wins: 125/250
# Starting training for Batch: 19 /841 and Epoch: 1
# (2767, 29, 28) (2767, 26) (2767, 26)
# 11/11 [==============================] - 6s 547ms/step - loss: 2.5448
# Time taken in seconds to train the batch: 92.50061130523682
# Correct Guesses: 1542/2767 , number of wins: 104/250
# Starting training for Batch: 20 /841 and Epoch: 1
# (2707, 29, 28) (2707, 26) (2707, 26)
# 11/11 [==============================] - 6s 538ms/step - loss: 2.5119
# Time taken in seconds to train the batch: 90.79345226287842
# Correct Guesses: 1604/2707 , number of wins: 127/250
# Starting training for Batch: 21 /841 and Epoch: 1
# (2760, 29, 28) (2760, 26) (2760, 26)
# 11/11 [==============================] - 6s 550ms/step - loss: 2.5101
# Time taken in seconds to train the batch: 92.30553078651428
# Correct Guesses: 1612/2760 , number of wins: 126/250
# Starting training for Batch: 22 /841 and Epoch: 1
# (2748, 29, 28) (2748, 26) (2748, 26)
# 11/11 [==============================] - 6s 551ms/step - loss: 2.5415
# Time taken in seconds to train the batch: 91.90011286735535
# Correct Guesses: 1516/2748 , number of wins: 98/250
# Starting training for Batch: 23 /841 and Epoch: 1
# (2792, 29, 28) (2792, 26) (2792, 26)
# 11/11 [==============================] - 6s 556ms/step - loss: 2.4928
# Time taken in seconds to train the batch: 93.37764573097229
# Correct Guesses: 1649/2792 , number of wins: 124/250
# Starting training for Batch: 24 /841 and Epoch: 1
# (2756, 29, 28) (2756, 26) (2756, 26)
# 11/11 [==============================] - 6s 555ms/step - loss: 2.5447
# Time taken in seconds to train the batch: 92.25146293640137
# Correct Guesses: 1556/2756 , number of wins: 110/250
# Starting training for Batch: 25 /841 and Epoch: 1
# (2765, 29, 28) (2765, 26) (2765, 26)
# 11/11 [==============================] - 6s 554ms/step - loss: 2.5112
# Time taken in seconds to train the batch: 92.71946358680725
# Correct Guesses: 1590/2765 , number of wins: 110/250
# Starting training for Batch: 26 /841 and Epoch: 1
# (2715, 29, 28) (2715, 26) (2715, 26)
# 11/11 [==============================] - 6s 554ms/step - loss: 2.5038
# Time taken in seconds to train the batch: 91.00844740867615
# Correct Guesses: 1570/2715 , number of wins: 128/250
# Starting training for Batch: 27 /841 and Epoch: 1
# (2743, 29, 28) (2743, 26) (2743, 26)
# 11/11 [==============================] - 6s 560ms/step - loss: 2.4762
# Time taken in seconds to train the batch: 91.91854214668274
# Correct Guesses: 1611/2743 , number of wins: 126/250
# Starting training for Batch: 28 /841 and Epoch: 1
# (2793, 29, 28) (2793, 26) (2793, 26)
# 11/11 [==============================] - 6s 570ms/step - loss: 2.4980
# Time taken in seconds to train the batch: 93.53413367271423
# Correct Guesses: 1606/2793 , number of wins: 111/250
# Starting training for Batch: 29 /841 and Epoch: 1
# (2751, 29, 28) (2751, 26) (2751, 26)
# 11/11 [==============================] - 6s 563ms/step - loss: 2.4647
# Time taken in seconds to train the batch: 92.204354763031
# Correct Guesses: 1636/2751 , number of wins: 138/250
# Starting training for Batch: 30 /841 and Epoch: 1
# (2715, 29, 28) (2715, 26) (2715, 26)
# 11/11 [==============================] - 6s 570ms/step - loss: 2.5284
# Time taken in seconds to train the batch: 91.31371259689331
# Correct Guesses: 1547/2715 , number of wins: 114/250
# Starting training for Batch: 31 /841 and Epoch: 1
# (2713, 29, 28) (2713, 26) (2713, 26)
# 11/11 [==============================] - 6s 568ms/step - loss: 2.5159
# Time taken in seconds to train the batch: 91.27809762954712
# Correct Guesses: 1578/2713 , number of wins: 128/250
# Starting training for Batch: 32 /841 and Epoch: 1
# (2772, 29, 28) (2772, 26) (2772, 26)
# 11/11 [==============================] - 6s 570ms/step - loss: 2.5009
# Time taken in seconds to train the batch: 95.28073811531067
# Correct Guesses: 1617/2772 , number of wins: 118/250
# Starting training for Batch: 33 /841 and Epoch: 1
# (2746, 29, 28) (2746, 26) (2746, 26)
# 11/11 [==============================] - 6s 580ms/step - loss: 2.5030
# Time taken in seconds to train the batch: 93.41213941574097
# Correct Guesses: 1595/2746 , number of wins: 125/250
# Starting training for Batch: 34 /841 and Epoch: 1
# (2663, 29, 28) (2663, 26) (2663, 26)
# 11/11 [==============================] - 6s 563ms/step - loss: 2.5513
# Time taken in seconds to train the batch: 90.78503060340881
# Correct Guesses: 1464/2663 , number of wins: 108/250
# Starting training for Batch: 35 /841 and Epoch: 1
# (2775, 29, 28) (2775, 26) (2775, 26)
# 11/11 [==============================] - 6s 578ms/step - loss: 2.5032
# Time taken in seconds to train the batch: 94.72660160064697
# Correct Guesses: 1644/2775 , number of wins: 130/250
# Starting training for Batch: 36 /841 and Epoch: 1
# (2809, 29, 28) (2809, 26) (2809, 26)
# 11/11 [==============================] - 6s 586ms/step - loss: 2.5170
# Time taken in seconds to train the batch: 95.61207580566406
# Correct Guesses: 1643/2809 , number of wins: 115/250
# Starting training for Batch: 37 /841 and Epoch: 1
# (2795, 29, 28) (2795, 26) (2795, 26)
# 11/11 [==============================] - 7s 614ms/step - loss: 2.5321
# Time taken in seconds to train the batch: 95.45639133453369
# Correct Guesses: 1625/2795 , number of wins: 115/250
# Starting training for Batch: 38 /841 and Epoch: 1
# (2784, 29, 28) (2784, 26) (2784, 26)
# 11/11 [==============================] - 6s 586ms/step - loss: 2.5008
# Time taken in seconds to train the batch: 95.09413003921509
# Correct Guesses: 1601/2784 , number of wins: 118/250
# Starting training for Batch: 39 /841 and Epoch: 1
# (2789, 29, 28) (2789, 26) (2789, 26)
# 11/11 [==============================] - 6s 584ms/step - loss: 2.5242
# Time taken in seconds to train the batch: 94.93111157417297
# Correct Guesses: 1597/2789 , number of wins: 115/250
# Starting training for Batch: 40 /841 and Epoch: 1
# (2780, 29, 28) (2780, 26) (2780, 26)
# 11/11 [==============================] - 6s 586ms/step - loss: 2.4918
# Time taken in seconds to train the batch: 94.57293057441711
# Correct Guesses: 1610/2780 , number of wins: 121/250
# Starting training for Batch: 41 /841 and Epoch: 1
# (2729, 29, 28) (2729, 26) (2729, 26)
# 11/11 [==============================] - 6s 584ms/step - loss: 2.5301
# Time taken in seconds to train the batch: 92.99639964103699
# Correct Guesses: 1548/2729 , number of wins: 109/250
# Starting training for Batch: 42 /841 and Epoch: 1
# (2735, 29, 28) (2735, 26) (2735, 26)
# 11/11 [==============================] - 7s 597ms/step - loss: 2.5011
# Time taken in seconds to train the batch: 93.40745973587036
# Correct Guesses: 1568/2735 , number of wins: 120/250
# Starting training for Batch: 43 /841 and Epoch: 1
# (2780, 29, 28) (2780, 26) (2780, 26)
# 11/11 [==============================] - 6s 589ms/step - loss: 2.5326
# Time taken in seconds to train the batch: 94.7089433670044
# Correct Guesses: 1611/2780 , number of wins: 115/250
# Starting training for Batch: 44 /841 and Epoch: 1
# (2720, 29, 28) (2720, 26) (2720, 26)
# 11/11 [==============================] - 7s 598ms/step - loss: 2.5021
# Time taken in seconds to train the batch: 93.11493229866028
# Correct Guesses: 1579/2720 , number of wins: 125/250
# Starting training for Batch: 45 /841 and Epoch: 1
# (2757, 29, 28) (2757, 26) (2757, 26)
# 11/11 [==============================] - 6s 591ms/step - loss: 2.5030
# Time taken in seconds to train the batch: 94.27552032470703
# Correct Guesses: 1612/2757 , number of wins: 126/250
# Starting training for Batch: 46 /841 and Epoch: 1
# (2789, 29, 28) (2789, 26) (2789, 26)
# 11/11 [==============================] - 7s 597ms/step - loss: 2.5106
# Time taken in seconds to train the batch: 95.26517796516418
# Correct Guesses: 1621/2789 , number of wins: 113/250
# Starting training for Batch: 47 /841 and Epoch: 1
# (2782, 29, 28) (2782, 26) (2782, 26)
# 11/11 [==============================] - 7s 600ms/step - loss: 2.4769
# Time taken in seconds to train the batch: 95.16217732429504
# Correct Guesses: 1622/2782 , number of wins: 129/250
# Starting training for Batch: 48 /841 and Epoch: 1
# (2805, 29, 28) (2805, 26) (2805, 26)
# 11/11 [==============================] - 7s 613ms/step - loss: 2.4877
# Time taken in seconds to train the batch: 95.96207356452942
# Correct Guesses: 1666/2805 , number of wins: 127/250
# Starting training for Batch: 49 /841 and Epoch: 1
# (2746, 29, 28) (2746, 26) (2746, 26)
# 11/11 [==============================] - 7s 615ms/step - loss: 2.4796
# Time taken in seconds to train the batch: 94.3648681640625
# Correct Guesses: 1620/2746 , number of wins: 125/250
# Starting training for Batch: 50 /841 and Epoch: 1
# (2779, 29, 28) (2779, 26) (2779, 26)
# 11/11 [==============================] - 7s 683ms/step - loss: 2.5119
# Time taken in seconds to train the batch: 96.99156665802002
# Correct Guesses: 1619/2779 , number of wins: 115/250
# Starting training for Batch: 51 /841 and Epoch: 1
# (2788, 29, 28) (2788, 26) (2788, 26)
# 11/11 [==============================] - 8s 692ms/step - loss: 2.5163
# Time taken in seconds to train the batch: 97.37492394447327
# Correct Guesses: 1605/2788 , number of wins: 114/250
# Starting training for Batch: 52 /841 and Epoch: 1
# (2837, 29, 28) (2837, 26) (2837, 26)
# 12/12 [==============================] - 8s 655ms/step - loss: 2.5031
# Time taken in seconds to train the batch: 99.36783647537231
# Correct Guesses: 1722/2837 , number of wins: 131/250
# Starting training for Batch: 53 /841 and Epoch: 1
# (2801, 29, 28) (2801, 26) (2801, 26)
# 11/11 [==============================] - 8s 703ms/step - loss: 2.5198
# Time taken in seconds to train the batch: 97.92754817008972
# Correct Guesses: 1644/2801 , number of wins: 125/250
# Starting training for Batch: 54 /841 and Epoch: 1
# (2782, 29, 28) (2782, 26) (2782, 26)
# 11/11 [==============================] - 8s 698ms/step - loss: 2.5254
# Time taken in seconds to train the batch: 97.47348856925964
# Correct Guesses: 1609/2782 , number of wins: 117/250
# Starting training for Batch: 55 /841 and Epoch: 1
# (2815, 29, 28) (2815, 26) (2815, 26)
# 11/11 [==============================] - 8s 719ms/step - loss: 2.4853
# Time taken in seconds to train the batch: 98.67243123054504
# Correct Guesses: 1685/2815 , number of wins: 135/250
# Starting training for Batch: 56 /841 and Epoch: 1
# (2720, 29, 28) (2720, 26) (2720, 26)
# 11/11 [==============================] - 8s 712ms/step - loss: 2.5111
# Time taken in seconds to train the batch: 95.72446131706238
# Correct Guesses: 1584/2720 , number of wins: 122/250
# Starting training for Batch: 57 /841 and Epoch: 1
# (2787, 29, 28) (2787, 26) (2787, 26)
# 11/11 [==============================] - 8s 711ms/step - loss: 2.4945
# Time taken in seconds to train the batch: 97.64201617240906
# Correct Guesses: 1658/2787 , number of wins: 135/250
# Starting training for Batch: 58 /841 and Epoch: 1
# (2763, 29, 28) (2763, 26) (2763, 26)
# 11/11 [==============================] - 8s 725ms/step - loss: 2.4738
# Time taken in seconds to train the batch: 97.3380057811737
# Correct Guesses: 1627/2763 , number of wins: 123/250
# Starting training for Batch: 59 /841 and Epoch: 1
# (2825, 29, 28) (2825, 26) (2825, 26)
# 12/12 [==============================] - 8s 682ms/step - loss: 2.4603
# Time taken in seconds to train the batch: 99.72626566886902
# Correct Guesses: 1707/2825 , number of wins: 141/250
# Starting training for Batch: 60 /841 and Epoch: 1
# (2747, 29, 28) (2747, 26) (2747, 26)
# 11/11 [==============================] - 10s 975ms/step - loss: 2.5332
# Time taken in seconds to train the batch: 101.1044089794159
# Correct Guesses: 1576/2747 , number of wins: 120/250
# Starting training for Batch: 61 /841 and Epoch: 1
# (2758, 29, 28) (2758, 26) (2758, 26)
# 11/11 [==============================] - 8s 714ms/step - loss: 2.4847
# Time taken in seconds to train the batch: 97.01331114768982
# Correct Guesses: 1654/2758 , number of wins: 130/250
# Starting training for Batch: 62 /841 and Epoch: 1
# (2673, 29, 28) (2673, 26) (2673, 26)
# 11/11 [==============================] - 8s 719ms/step - loss: 2.5083
# Time taken in seconds to train the batch: 97.84319543838501
# Correct Guesses: 1508/2673 , number of wins: 116/250
# Starting training for Batch: 63 /841 and Epoch: 1
# (2768, 29, 28) (2768, 26) (2768, 26)
# 11/11 [==============================] - 8s 716ms/step - loss: 2.5036
# Time taken in seconds to train the batch: 96.40946769714355
# Correct Guesses: 1619/2768 , number of wins: 121/250
# Starting training for Batch: 64 /841 and Epoch: 1
# (2815, 29, 28) (2815, 26) (2815, 26)
# 11/11 [==============================] - 9s 809ms/step - loss: 2.4860
# Time taken in seconds to train the batch: 101.66428852081299
# Correct Guesses: 1672/2815 , number of wins: 128/250
# Starting training for Batch: 65 /841 and Epoch: 1
# (2776, 29, 28) (2776, 26) (2776, 26)
# 11/11 [==============================] - 9s 801ms/step - loss: 2.4835
# Time taken in seconds to train the batch: 107.03901791572571
# Correct Guesses: 1659/2776 , number of wins: 126/250
# Starting training for Batch: 66 /841 and Epoch: 1
# (2668, 29, 28) (2668, 26) (2668, 26)
# 11/11 [==============================] - 9s 814ms/step - loss: 2.5450
# Time taken in seconds to train the batch: 103.59989070892334
# Correct Guesses: 1531/2668 , number of wins: 119/250
# Starting training for Batch: 67 /841 and Epoch: 1
# (2730, 29, 28) (2730, 26) (2730, 26)
# 11/11 [==============================] - 9s 822ms/step - loss: 2.5076
# Time taken in seconds to train the batch: 105.80097508430481
# Correct Guesses: 1598/2730 , number of wins: 124/250
# Starting training for Batch: 68 /841 and Epoch: 1
# (2744, 29, 28) (2744, 26) (2744, 26)
# 11/11 [==============================] - 9s 865ms/step - loss: 2.5164
# Time taken in seconds to train the batch: 106.42937397956848
# Correct Guesses: 1609/2744 , number of wins: 120/250
# Starting training for Batch: 69 /841 and Epoch: 1
# (2750, 29, 28) (2750, 26) (2750, 26)
# 11/11 [==============================] - 9s 856ms/step - loss: 2.4774
# Time taken in seconds to train the batch: 106.62060904502869
# Correct Guesses: 1633/2750 , number of wins: 144/250
# Starting training for Batch: 70 /841 and Epoch: 1
# (2739, 29, 28) (2739, 26) (2739, 26)
# 11/11 [==============================] - 10s 883ms/step - loss: 2.5022
# Time taken in seconds to train the batch: 106.09857678413391
# Correct Guesses: 1608/2739 , number of wins: 130/250
# Starting training for Batch: 71 /841 and Epoch: 1
# (2829, 29, 28) (2829, 26) (2829, 26)
# 12/12 [==============================] - 9s 775ms/step - loss: 2.4842
# Time taken in seconds to train the batch: 110.0716061592102
# Correct Guesses: 1711/2829 , number of wins: 136/250
# Starting training for Batch: 72 /841 and Epoch: 1
# (2706, 29, 28) (2706, 26) (2706, 26)
# 11/11 [==============================] - 9s 849ms/step - loss: 2.4771
# Time taken in seconds to train the batch: 104.9326868057251
# Correct Guesses: 1569/2706 , number of wins: 123/250
# Starting training for Batch: 73 /841 and Epoch: 1
# (2810, 29, 28) (2810, 26) (2810, 26)
# 11/11 [==============================] - 9s 835ms/step - loss: 2.5198
# Time taken in seconds to train the batch: 109.69607019424438
# Correct Guesses: 1606/2810 , number of wins: 117/250
# Starting training for Batch: 74 /841 and Epoch: 1
# (2810, 29, 28) (2810, 26) (2810, 26)
# 11/11 [==============================] - 9s 856ms/step - loss: 2.4844
# Time taken in seconds to train the batch: 108.81999564170837
# Correct Guesses: 1632/2810 , number of wins: 132/250
# Starting training for Batch: 75 /841 and Epoch: 1
# (2752, 29, 28) (2752, 26) (2752, 26)
# 11/11 [==============================] - 10s 892ms/step - loss: 2.5300
# Time taken in seconds to train the batch: 107.5511167049408
# Correct Guesses: 1616/2752 , number of wins: 132/250
# Starting training for Batch: 76 /841 and Epoch: 1
# (2744, 29, 28) (2744, 26) (2744, 26)
# 11/11 [==============================] - 10s 908ms/step - loss: 2.5433
# Time taken in seconds to train the batch: 107.13808798789978
# Correct Guesses: 1577/2744 , number of wins: 114/250
# Starting training for Batch: 77 /841 and Epoch: 1
# (2760, 29, 28) (2760, 26) (2760, 26)
# 11/11 [==============================] - 9s 860ms/step - loss: 2.5123
# Time taken in seconds to train the batch: 107.24075770378113
# Correct Guesses: 1630/2760 , number of wins: 127/250
# Starting training for Batch: 78 /841 and Epoch: 1
# (2776, 29, 28) (2776, 26) (2776, 26)
# 11/11 [==============================] - 10s 867ms/step - loss: 2.5442
# Time taken in seconds to train the batch: 108.22534656524658
# Correct Guesses: 1577/2776 , number of wins: 115/250
# Starting training for Batch: 79 /841 and Epoch: 1
# (2786, 29, 28) (2786, 26) (2786, 26)
# 11/11 [==============================] - 10s 878ms/step - loss: 2.4982
# Time taken in seconds to train the batch: 108.47470545768738
# Correct Guesses: 1621/2786 , number of wins: 121/250
# Starting training for Batch: 80 /841 and Epoch: 1
# (2758, 29, 28) (2758, 26) (2758, 26)
# 11/11 [==============================] - 10s 889ms/step - loss: 2.5165
# Time taken in seconds to train the batch: 107.4824104309082
# Correct Guesses: 1610/2758 , number of wins: 126/250
# Starting training for Batch: 81 /841 and Epoch: 1
# (2741, 29, 28) (2741, 26) (2741, 26)
# 11/11 [==============================] - 9s 850ms/step - loss: 2.5199
# Time taken in seconds to train the batch: 99.66083335876465
# Correct Guesses: 1595/2741 , number of wins: 123/250
# Starting training for Batch: 82 /841 and Epoch: 1
# (2748, 29, 28) (2748, 26) (2748, 26)
# 11/11 [==============================] - 10s 950ms/step - loss: 2.4878
# Time taken in seconds to train the batch: 100.94899559020996
# Correct Guesses: 1634/2748 , number of wins: 132/250
# Starting training for Batch: 83 /841 and Epoch: 1
# (2784, 29, 28) (2784, 26) (2784, 26)
# 11/11 [==============================] - 9s 828ms/step - loss: 2.4731
# Time taken in seconds to train the batch: 104.94471096992493
# Correct Guesses: 1602/2784 , number of wins: 122/250
# Starting training for Batch: 84 /841 and Epoch: 1
# (2767, 29, 28) (2767, 26) (2767, 26)
# 11/11 [==============================] - 10s 917ms/step - loss: 2.4839
# Time taken in seconds to train the batch: 107.84964632987976
# Correct Guesses: 1618/2767 , number of wins: 125/250
# Starting training for Batch: 85 /841 and Epoch: 1
# (2737, 29, 28) (2737, 26) (2737, 26)
# 11/11 [==============================] - 11s 967ms/step - loss: 2.4998
# Time taken in seconds to train the batch: 108.6498692035675
# Correct Guesses: 1606/2737 , number of wins: 127/250
# Starting training for Batch: 86 /841 and Epoch: 1
# (2778, 29, 28) (2778, 26) (2778, 26)
# 11/11 [==============================] - 9s 851ms/step - loss: 2.4946
# Time taken in seconds to train the batch: 104.79341197013855
# Correct Guesses: 1631/2778 , number of wins: 126/250
# Starting training for Batch: 87 /841 and Epoch: 1
# (2749, 29, 28) (2749, 26) (2749, 26)
# 11/11 [==============================] - 10s 911ms/step - loss: 2.5113
# Time taken in seconds to train the batch: 98.59359884262085
# Correct Guesses: 1600/2749 , number of wins: 127/250
# Starting training for Batch: 88 /841 and Epoch: 1
# (2811, 29, 28) (2811, 26) (2811, 26)
# 11/11 [==============================] - 11s 967ms/step - loss: 2.4958
# Time taken in seconds to train the batch: 106.28726887702942
# Correct Guesses: 1628/2811 , number of wins: 117/250
# Starting training for Batch: 89 /841 and Epoch: 1
# (2702, 29, 28) (2702, 26) (2702, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4721
# Time taken in seconds to train the batch: 106.78594326972961
# Correct Guesses: 1571/2702 , number of wins: 129/250
# Starting training for Batch: 90 /841 and Epoch: 1
# (2784, 29, 28) (2784, 26) (2784, 26)
# 11/11 [==============================] - 11s 971ms/step - loss: 2.5049
# Time taken in seconds to train the batch: 110.14492273330688
# Correct Guesses: 1674/2784 , number of wins: 128/250
# Starting training for Batch: 91 /841 and Epoch: 1
# (2775, 29, 28) (2775, 26) (2775, 26)
# 11/11 [==============================] - 11s 974ms/step - loss: 2.5283
# Time taken in seconds to train the batch: 109.73759698867798
# Correct Guesses: 1582/2775 , number of wins: 106/250
# Starting training for Batch: 92 /841 and Epoch: 1
# (2730, 29, 28) (2730, 26) (2730, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4940
# Time taken in seconds to train the batch: 108.16635632514954
# Correct Guesses: 1612/2730 , number of wins: 133/250
# Starting training for Batch: 93 /841 and Epoch: 1
# (2749, 29, 28) (2749, 26) (2749, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5044
# Time taken in seconds to train the batch: 109.84275126457214
# Correct Guesses: 1602/2749 , number of wins: 129/250
# Starting training for Batch: 94 /841 and Epoch: 1
# (2774, 29, 28) (2774, 26) (2774, 26)
# 11/11 [==============================] - 11s 998ms/step - loss: 2.5139
# Time taken in seconds to train the batch: 109.90742087364197
# Correct Guesses: 1598/2774 , number of wins: 125/250
# Starting training for Batch: 95 /841 and Epoch: 1
# (2701, 29, 28) (2701, 26) (2701, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5050
# Time taken in seconds to train the batch: 107.82432174682617
# Correct Guesses: 1539/2701 , number of wins: 123/250
# Starting training for Batch: 96 /841 and Epoch: 1
# (2694, 29, 28) (2694, 26) (2694, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5422
# Time taken in seconds to train the batch: 107.29547166824341
# Correct Guesses: 1538/2694 , number of wins: 115/250
# Starting training for Batch: 97 /841 and Epoch: 1
# (2740, 29, 28) (2740, 26) (2740, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5184
# Time taken in seconds to train the batch: 109.7799506187439
# Correct Guesses: 1598/2740 , number of wins: 129/250
# Starting training for Batch: 98 /841 and Epoch: 1
# (2770, 29, 28) (2770, 26) (2770, 26)
# 11/11 [==============================] - 11s 969ms/step - loss: 2.5509
# Time taken in seconds to train the batch: 102.76066136360168
# Correct Guesses: 1561/2770 , number of wins: 104/250
# Starting training for Batch: 99 /841 and Epoch: 1
# (2744, 29, 28) (2744, 26) (2744, 26)
# 11/11 [==============================] - 11s 999ms/step - loss: 2.5233
# Time taken in seconds to train the batch: 99.75958299636841
# Correct Guesses: 1611/2744 , number of wins: 122/250
# Starting training for Batch: 100 /841 and Epoch: 1
# (2794, 29, 28) (2794, 26) (2794, 26)
# 11/11 [==============================] - 10s 933ms/step - loss: 2.4664
# Time taken in seconds to train the batch: 100.76357817649841
# Correct Guesses: 1707/2794 , number of wins: 138/250
# Starting training for Batch: 101 /841 and Epoch: 1
# (2752, 29, 28) (2752, 26) (2752, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5153
# Time taken in seconds to train the batch: 100.28938174247742
# Correct Guesses: 1602/2752 , number of wins: 128/250
# Starting training for Batch: 102 /841 and Epoch: 1
# (2752, 29, 28) (2752, 26) (2752, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4837
# Time taken in seconds to train the batch: 100.2298035621643
# Correct Guesses: 1612/2752 , number of wins: 128/250
# Starting training for Batch: 103 /841 and Epoch: 1
# (2701, 29, 28) (2701, 26) (2701, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5338
# Time taken in seconds to train the batch: 98.5342230796814
# Correct Guesses: 1530/2701 , number of wins: 115/250
# Starting training for Batch: 104 /841 and Epoch: 1
# (2739, 29, 28) (2739, 26) (2739, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4991
# Time taken in seconds to train the batch: 99.88357949256897
# Correct Guesses: 1590/2739 , number of wins: 125/250
# Starting training for Batch: 105 /841 and Epoch: 1
# (2750, 29, 28) (2750, 26) (2750, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.5133
# Time taken in seconds to train the batch: 100.4444420337677
# Correct Guesses: 1586/2750 , number of wins: 120/250
# Starting training for Batch: 106 /841 and Epoch: 1
# (2764, 29, 28) (2764, 26) (2764, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4854
# Time taken in seconds to train the batch: 100.81165146827698
# Correct Guesses: 1641/2764 , number of wins: 132/250
# Starting training for Batch: 107 /841 and Epoch: 1
# (2754, 29, 28) (2754, 26) (2754, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4938
# Time taken in seconds to train the batch: 100.87652087211609
# Correct Guesses: 1591/2754 , number of wins: 119/250
# Starting training for Batch: 108 /841 and Epoch: 1
# (2793, 29, 28) (2793, 26) (2793, 26)
# 11/11 [==============================] - 11s 995ms/step - loss: 2.5171
# Time taken in seconds to train the batch: 101.64309477806091
# Correct Guesses: 1637/2793 , number of wins: 121/250
# Starting training for Batch: 109 /841 and Epoch: 1
# (2797, 29, 28) (2797, 26) (2797, 26)
# 11/11 [==============================] - 11s 1s/step - loss: 2.4812
# Time taken in seconds to train the batch: 101.94189882278442
# Correct Guesses: 1676/2797 , number of wins: 140/250
# Starting training for Batch: 110 /841 and Epoch: 1
# (2751, 29, 28) (2751, 26) (2751, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.4966
# Time taken in seconds to train the batch: 101.34861874580383
# Correct Guesses: 1600/2751 , number of wins: 122/250
# Starting training for Batch: 111 /841 and Epoch: 1
# (2734, 29, 28) (2734, 26) (2734, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5143
# Time taken in seconds to train the batch: 100.7116756439209
# Correct Guesses: 1567/2734 , number of wins: 122/250
# Starting training for Batch: 112 /841 and Epoch: 1
# (2710, 29, 28) (2710, 26) (2710, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5100
# Time taken in seconds to train the batch: 99.68064975738525
# Correct Guesses: 1558/2710 , number of wins: 122/250
# Starting training for Batch: 113 /841 and Epoch: 1
# (2771, 29, 28) (2771, 26) (2771, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5316
# Time taken in seconds to train the batch: 101.77770137786865
# Correct Guesses: 1626/2771 , number of wins: 124/250
# Starting training for Batch: 114 /841 and Epoch: 1
# (2770, 29, 28) (2770, 26) (2770, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.4932
# Time taken in seconds to train the batch: 101.99415922164917
# Correct Guesses: 1631/2770 , number of wins: 138/250
# Starting training for Batch: 115 /841 and Epoch: 1
# (2814, 29, 28) (2814, 26) (2814, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5081
# Time taken in seconds to train the batch: 103.46458196640015
# Correct Guesses: 1621/2814 , number of wins: 119/250
# Starting training for Batch: 116 /841 and Epoch: 1
# (2732, 29, 28) (2732, 26) (2732, 26)
# 11/11 [==============================] - 13s 1s/step - loss: 2.5000
# Time taken in seconds to train the batch: 101.74806571006775
# Correct Guesses: 1560/2732 , number of wins: 123/250
# Starting training for Batch: 117 /841 and Epoch: 1
# (2748, 29, 28) (2748, 26) (2748, 26)
# 11/11 [==============================] - 13s 1s/step - loss: 2.4890
# Time taken in seconds to train the batch: 102.24320936203003
# Correct Guesses: 1595/2748 , number of wins: 120/250
# Starting training for Batch: 118 /841 and Epoch: 1
# (2725, 29, 28) (2725, 26) (2725, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5259
# Time taken in seconds to train the batch: 100.92198467254639
# Correct Guesses: 1566/2725 , number of wins: 118/250
# Starting training for Batch: 119 /841 and Epoch: 1
# (2705, 29, 28) (2705, 26) (2705, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5190
# Time taken in seconds to train the batch: 100.66959953308105
# Correct Guesses: 1566/2705 , number of wins: 117/250
# Starting training for Batch: 120 /841 and Epoch: 1
# (2774, 29, 28) (2774, 26) (2774, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5259
# Time taken in seconds to train the batch: 102.7687475681305
# Correct Guesses: 1563/2774 , number of wins: 106/250
# Starting training for Batch: 121 /841 and Epoch: 1
# (2772, 29, 28) (2772, 26) (2772, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.4941
# Time taken in seconds to train the batch: 102.96828842163086
# Correct Guesses: 1579/2772 , number of wins: 115/250
# Starting training for Batch: 122 /841 and Epoch: 1
# (2787, 29, 28) (2787, 26) (2787, 26)
# 11/11 [==============================] - 12s 1s/step - loss: 2.5046
# Time taken in seconds to train the batch: 103.5670166015625
# Correct Guesses: 1624/2787 , number of wins: 127/250
# Starting training for Batch: 123 /841 and Epoch: 1
# (2729, 29, 28) (2729, 26) (2729, 26)
# 11/11 [==============================] - 13s 1s/step - loss: 2.4743
# Time taken in seconds to train the batch: 101.89272809028625
# Correct Guesses: 1614/2729 , number of wins: 135/250
# Starting training for Batch: 124 /841 and Epoch: 1
# (2739, 29, 28) (2739, 26) (2739, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.5132
# Time taken in seconds to train the batch: 105.21738195419312
# Correct Guesses: 1544/2739 , number of wins: 118/250
# Starting training for Batch: 125 /841 and Epoch: 1
# (2795, 29, 28) (2795, 26) (2795, 26)
# 11/11 [==============================] - 13s 1s/step - loss: 2.5015
# Time taken in seconds to train the batch: 120.38543939590454
# Correct Guesses: 1633/2795 , number of wins: 124/250
# Starting training for Batch: 126 /841 and Epoch: 1
# (2746, 29, 28) (2746, 26) (2746, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.5118
# Time taken in seconds to train the batch: 112.9996268749237
# Correct Guesses: 1577/2746 , number of wins: 117/250
# Starting training for Batch: 127 /841 and Epoch: 1
# (2747, 29, 28) (2747, 26) (2747, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4788
# Time taken in seconds to train the batch: 113.32623934745789
# Correct Guesses: 1591/2747 , number of wins: 120/250
# Starting training for Batch: 128 /841 and Epoch: 1
# (2750, 29, 28) (2750, 26) (2750, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4772
# Time taken in seconds to train the batch: 114.15467667579651
# Correct Guesses: 1644/2750 , number of wins: 136/250
# Starting training for Batch: 129 /841 and Epoch: 1
# (2706, 29, 28) (2706, 26) (2706, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.5043
# Time taken in seconds to train the batch: 111.93268132209778
# Correct Guesses: 1545/2706 , number of wins: 128/250
# Starting training for Batch: 130 /841 and Epoch: 1
# (2770, 29, 28) (2770, 26) (2770, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.4541
# Time taken in seconds to train the batch: 114.45638537406921
# Correct Guesses: 1650/2770 , number of wins: 144/250
# Starting training for Batch: 131 /841 and Epoch: 1
# (2710, 29, 28) (2710, 26) (2710, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.5036
# Time taken in seconds to train the batch: 112.4304141998291
# Correct Guesses: 1558/2710 , number of wins: 128/250
# Starting training for Batch: 132 /841 and Epoch: 1
# (2744, 29, 28) (2744, 26) (2744, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.5081
# Time taken in seconds to train the batch: 114.40058636665344
# Correct Guesses: 1572/2744 , number of wins: 120/250
# Starting training for Batch: 133 /841 and Epoch: 1
# (2772, 29, 28) (2772, 26) (2772, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4963
# Time taken in seconds to train the batch: 114.75056767463684
# Correct Guesses: 1609/2772 , number of wins: 127/250
# Starting training for Batch: 134 /841 and Epoch: 1
# (2758, 29, 28) (2758, 26) (2758, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.5072
# Time taken in seconds to train the batch: 114.34940934181213
# Correct Guesses: 1579/2758 , number of wins: 114/250
# Starting training for Batch: 135 /841 and Epoch: 1
# (2818, 29, 28) (2818, 26) (2818, 26)
# 12/12 [==============================] - 15s 1s/step - loss: 2.5138
# Time taken in seconds to train the batch: 116.9502866268158
# Correct Guesses: 1628/2818 , number of wins: 123/250
# Starting training for Batch: 136 /841 and Epoch: 1
# (2795, 29, 28) (2795, 26) (2795, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4960
# Time taken in seconds to train the batch: 116.89675569534302
# Correct Guesses: 1648/2795 , number of wins: 128/250
# Starting training for Batch: 137 /841 and Epoch: 1
# (2751, 29, 28) (2751, 26) (2751, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.5266
# Time taken in seconds to train the batch: 108.16639709472656
# Correct Guesses: 1571/2751 , number of wins: 118/250
# Starting training for Batch: 138 /841 and Epoch: 1
# (2846, 29, 28) (2846, 26) (2846, 26)
# 12/12 [==============================] - 14s 1s/step - loss: 2.4779
# Time taken in seconds to train the batch: 111.65843510627747
# Correct Guesses: 1695/2846 , number of wins: 133/250
# Starting training for Batch: 139 /841 and Epoch: 1
# (2793, 29, 28) (2793, 26) (2793, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4609
# Time taken in seconds to train the batch: 114.24790000915527
# Correct Guesses: 1685/2793 , number of wins: 141/250
# Starting training for Batch: 140 /841 and Epoch: 1
# (2771, 29, 28) (2771, 26) (2771, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.4965
# Time taken in seconds to train the batch: 109.76484608650208
# Correct Guesses: 1579/2771 , number of wins: 116/250
# Starting training for Batch: 141 /841 and Epoch: 1
# (2754, 29, 28) (2754, 26) (2754, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.5126
# Time taken in seconds to train the batch: 105.13721752166748
# Correct Guesses: 1620/2754 , number of wins: 132/250
# Starting training for Batch: 142 /841 and Epoch: 1
# (2764, 29, 28) (2764, 26) (2764, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.4958
# Time taken in seconds to train the batch: 105.74719500541687
# Correct Guesses: 1639/2764 , number of wins: 123/250
# Starting training for Batch: 143 /841 and Epoch: 1
# (2846, 29, 28) (2846, 26) (2846, 26)
# 12/12 [==============================] - 15s 1s/step - loss: 2.4943
# Time taken in seconds to train the batch: 108.4770519733429
# Correct Guesses: 1671/2846 , number of wins: 120/250
# Starting training for Batch: 144 /841 and Epoch: 1
# (2789, 29, 28) (2789, 26) (2789, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.4985
# Time taken in seconds to train the batch: 106.39670705795288
# Correct Guesses: 1616/2789 , number of wins: 125/250
# Starting training for Batch: 145 /841 and Epoch: 1
# (2763, 29, 28) (2763, 26) (2763, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.5332
# Time taken in seconds to train the batch: 110.65018796920776
# Correct Guesses: 1540/2763 , number of wins: 103/250
# Starting training for Batch: 146 /841 and Epoch: 1
# (2718, 29, 28) (2718, 26) (2718, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4955
# Time taken in seconds to train the batch: 114.30881142616272
# Correct Guesses: 1583/2718 , number of wins: 127/250
# Starting training for Batch: 147 /841 and Epoch: 1
# (2739, 29, 28) (2739, 26) (2739, 26)
# 11/11 [==============================] - 16s 2s/step - loss: 2.5269
# Time taken in seconds to train the batch: 115.35073018074036
# Correct Guesses: 1551/2739 , number of wins: 114/250
# Starting training for Batch: 148 /841 and Epoch: 1
# (2777, 29, 28) (2777, 26) (2777, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4975
# Time taken in seconds to train the batch: 116.53808689117432
# Correct Guesses: 1616/2777 , number of wins: 126/250
# Starting training for Batch: 149 /841 and Epoch: 1
# (2736, 29, 28) (2736, 26) (2736, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4803
# Time taken in seconds to train the batch: 115.75917267799377
# Correct Guesses: 1607/2736 , number of wins: 131/250
# Starting training for Batch: 150 /841 and Epoch: 1
# (2701, 29, 28) (2701, 26) (2701, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.5512
# Time taken in seconds to train the batch: 114.12682747840881
# Correct Guesses: 1496/2701 , number of wins: 101/250
# Starting training for Batch: 151 /841 and Epoch: 1
# (2740, 29, 28) (2740, 26) (2740, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4860
# Time taken in seconds to train the batch: 116.28602170944214
# Correct Guesses: 1591/2740 , number of wins: 124/250
# Starting training for Batch: 152 /841 and Epoch: 1
# (2786, 29, 28) (2786, 26) (2786, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4931
# Time taken in seconds to train the batch: 117.66881084442139
# Correct Guesses: 1619/2786 , number of wins: 125/250
# Starting training for Batch: 153 /841 and Epoch: 1
# (2713, 29, 28) (2713, 26) (2713, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4856
# Time taken in seconds to train the batch: 114.43941330909729
# Correct Guesses: 1584/2713 , number of wins: 123/250
# Starting training for Batch: 154 /841 and Epoch: 1
# (2755, 29, 28) (2755, 26) (2755, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4999
# Time taken in seconds to train the batch: 115.81080317497253
# Correct Guesses: 1613/2755 , number of wins: 122/250
# Starting training for Batch: 155 /841 and Epoch: 1
# (2763, 29, 28) (2763, 26) (2763, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4948
# Time taken in seconds to train the batch: 131.5288770198822
# Correct Guesses: 1637/2763 , number of wins: 125/250
# Starting training for Batch: 156 /841 and Epoch: 1
# (2744, 29, 28) (2744, 26) (2744, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4931
# Time taken in seconds to train the batch: 123.25025272369385
# Correct Guesses: 1607/2744 , number of wins: 127/250
# Starting training for Batch: 157 /841 and Epoch: 1
# (2755, 29, 28) (2755, 26) (2755, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4805
# Time taken in seconds to train the batch: 117.34970951080322
# Correct Guesses: 1633/2755 , number of wins: 130/250
# Starting training for Batch: 158 /841 and Epoch: 1
# (2775, 29, 28) (2775, 26) (2775, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.5014
# Time taken in seconds to train the batch: 117.679114818573
# Correct Guesses: 1634/2775 , number of wins: 129/250
# Starting training for Batch: 159 /841 and Epoch: 1
# (2777, 29, 28) (2777, 26) (2777, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4762
# Time taken in seconds to train the batch: 117.85121774673462
# Correct Guesses: 1660/2777 , number of wins: 131/250
# Starting training for Batch: 160 /841 and Epoch: 1
# (2740, 29, 28) (2740, 26) (2740, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4951
# Time taken in seconds to train the batch: 117.60968899726868
# Correct Guesses: 1614/2740 , number of wins: 130/250
# Starting training for Batch: 161 /841 and Epoch: 1
# (2770, 29, 28) (2770, 26) (2770, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.5209
# Time taken in seconds to train the batch: 118.10102272033691
# Correct Guesses: 1597/2770 , number of wins: 127/250
# Starting training for Batch: 162 /841 and Epoch: 1
# (2809, 29, 28) (2809, 26) (2809, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4846
# Time taken in seconds to train the batch: 119.22997689247131
# Correct Guesses: 1666/2809 , number of wins: 125/250
# Starting training for Batch: 163 /841 and Epoch: 1
# (2749, 29, 28) (2749, 26) (2749, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4922
# Time taken in seconds to train the batch: 117.76790475845337
# Correct Guesses: 1602/2749 , number of wins: 123/250
# Starting training for Batch: 164 /841 and Epoch: 1
# (2773, 29, 28) (2773, 26) (2773, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.5157
# Time taken in seconds to train the batch: 118.72118282318115
# Correct Guesses: 1620/2773 , number of wins: 117/250
# Starting training for Batch: 165 /841 and Epoch: 1
# (2757, 29, 28) (2757, 26) (2757, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4714
# Time taken in seconds to train the batch: 118.95120882987976
# Correct Guesses: 1622/2757 , number of wins: 126/250
# Starting training for Batch: 166 /841 and Epoch: 1
# (2752, 29, 28) (2752, 26) (2752, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.5249
# Time taken in seconds to train the batch: 118.93955850601196
# Correct Guesses: 1575/2752 , number of wins: 121/250
# Starting training for Batch: 167 /841 and Epoch: 1
# (2748, 29, 28) (2748, 26) (2748, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.5102
# Time taken in seconds to train the batch: 119.30928158760071
# Correct Guesses: 1575/2748 , number of wins: 120/250
# Starting training for Batch: 168 /841 and Epoch: 1
# (2789, 29, 28) (2789, 26) (2789, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4730
# Time taken in seconds to train the batch: 120.09082341194153
# Correct Guesses: 1644/2789 , number of wins: 136/250
# Starting training for Batch: 169 /841 and Epoch: 1
# (2777, 29, 28) (2777, 26) (2777, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4797
# Time taken in seconds to train the batch: 119.4944155216217
# Correct Guesses: 1639/2777 , number of wins: 135/250
# Starting training for Batch: 170 /841 and Epoch: 1
# (2791, 29, 28) (2791, 26) (2791, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4976
# Time taken in seconds to train the batch: 120.16465735435486
# Correct Guesses: 1659/2791 , number of wins: 133/250
# Starting training for Batch: 171 /841 and Epoch: 1
# (2804, 29, 28) (2804, 26) (2804, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.5001
# Time taken in seconds to train the batch: 120.94973468780518
# Correct Guesses: 1648/2804 , number of wins: 128/250
# Starting training for Batch: 172 /841 and Epoch: 1
# (2728, 29, 28) (2728, 26) (2728, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.5169
# Time taken in seconds to train the batch: 118.94422125816345
# Correct Guesses: 1564/2728 , number of wins: 113/250
# Starting training for Batch: 173 /841 and Epoch: 1
# (2737, 29, 28) (2737, 26) (2737, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4548
# Time taken in seconds to train the batch: 119.30706548690796
# Correct Guesses: 1671/2737 , number of wins: 139/250
# Starting training for Batch: 174 /841 and Epoch: 1
# (2810, 29, 28) (2810, 26) (2810, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4903
# Time taken in seconds to train the batch: 121.6089985370636
# Correct Guesses: 1704/2810 , number of wins: 129/250
# Starting training for Batch: 175 /841 and Epoch: 1
# (2772, 29, 28) (2772, 26) (2772, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4849
# Time taken in seconds to train the batch: 120.43136644363403
# Correct Guesses: 1609/2772 , number of wins: 122/250
# Starting training for Batch: 176 /841 and Epoch: 1
# (2735, 29, 28) (2735, 26) (2735, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.5226
# Time taken in seconds to train the batch: 120.78948712348938
# Correct Guesses: 1597/2735 , number of wins: 125/250
# Starting training for Batch: 177 /841 and Epoch: 1
# (2741, 29, 28) (2741, 26) (2741, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4785
# Time taken in seconds to train the batch: 121.0453851222992
# Correct Guesses: 1625/2741 , number of wins: 131/250
# Starting training for Batch: 178 /841 and Epoch: 1
# (2731, 29, 28) (2731, 26) (2731, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.5160
# ...
# (2746, 29, 28) (2746, 26) (2746, 26)
# 11/11 [==============================] - 157s 14s/step - loss: 2.4619
# Time taken in seconds to train the batch: 303.9353537559509
# Correct Guesses: 1617/2746 , number of wins: 127/250
# Starting training for Batch: 783 /841 and Epoch: 1
# (2728, 29, 28) (2728, 26) (2728, 26)
# 11/11 [==============================] - 155s 14s/step - loss: 2.4301
# Time taken in seconds to train the batch: 301.100182056427
# Correct Guesses: 1678/2728 , number of wins: 147/250
# Starting training for Batch: 784 /841 and Epoch: 1
# (2727, 29, 28) (2727, 26) (2727, 26)
# 11/11 [==============================] - 138s 13s/step - loss: 2.4662
# Time taken in seconds to train the batch: 277.0888206958771
# Correct Guesses: 1621/2727 , number of wins: 133/250
# Starting training for Batch: 785 /841 and Epoch: 1
# (2715, 29, 28) (2715, 26) (2715, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4768
# Time taken in seconds to train the batch: 275.64640283584595
# Correct Guesses: 1584/2715 , number of wins: 129/250
# Starting training for Batch: 786 /841 and Epoch: 1
# (2774, 29, 28) (2774, 26) (2774, 26)
# 11/11 [==============================] - 137s 12s/step - loss: 2.4313
# Time taken in seconds to train the batch: 269.21503806114197
# Correct Guesses: 1679/2774 , number of wins: 145/250
# Starting training for Batch: 787 /841 and Epoch: 1
# (2766, 29, 28) (2766, 26) (2766, 26)
# 11/11 [==============================] - 137s 12s/step - loss: 2.4754
# Time taken in seconds to train the batch: 271.53051471710205
# Correct Guesses: 1662/2766 , number of wins: 136/250
# Starting training for Batch: 788 /841 and Epoch: 1
# (2751, 29, 28) (2751, 26) (2751, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4871
# Time taken in seconds to train the batch: 273.997759103775
# Correct Guesses: 1650/2751 , number of wins: 132/250
# Starting training for Batch: 789 /841 and Epoch: 1
# (2749, 29, 28) (2749, 26) (2749, 26)
# 11/11 [==============================] - 141s 13s/step - loss: 2.4595
# Time taken in seconds to train the batch: 274.5983064174652
# Correct Guesses: 1645/2749 , number of wins: 134/250
# Starting training for Batch: 790 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4900
# Time taken in seconds to train the batch: 272.26971554756165
# Correct Guesses: 1644/2721 , number of wins: 136/250
# Starting training for Batch: 791 /841 and Epoch: 1
# (2725, 29, 28) (2725, 26) (2725, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4824
# Time taken in seconds to train the batch: 273.1739366054535
# Correct Guesses: 1651/2725 , number of wins: 138/250
# Starting training for Batch: 792 /841 and Epoch: 1
# (2777, 29, 28) (2777, 26) (2777, 26)
# 11/11 [==============================] - 139s 13s/step - loss: 2.4220
# Time taken in seconds to train the batch: 273.94715881347656
# Correct Guesses: 1679/2777 , number of wins: 142/250
# Starting training for Batch: 793 /841 and Epoch: 1
# (2736, 29, 28) (2736, 26) (2736, 26)
# 11/11 [==============================] - 142s 13s/step - loss: 2.4986
# Time taken in seconds to train the batch: 275.8359034061432
# Correct Guesses: 1599/2736 , number of wins: 132/250
# Starting training for Batch: 794 /841 and Epoch: 1
# (2710, 29, 28) (2710, 26) (2710, 26)
# 11/11 [==============================] - 141s 13s/step - loss: 2.4993
# Time taken in seconds to train the batch: 273.3677296638489
# Correct Guesses: 1589/2710 , number of wins: 133/250
# Starting training for Batch: 795 /841 and Epoch: 1
# (2684, 29, 28) (2684, 26) (2684, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4462
# Time taken in seconds to train the batch: 271.3977212905884
# Correct Guesses: 1599/2684 , number of wins: 145/250
# Starting training for Batch: 796 /841 and Epoch: 1
# (2752, 29, 28) (2752, 26) (2752, 26)
# 11/11 [==============================] - 142s 13s/step - loss: 2.4288
# Time taken in seconds to train the batch: 276.90457463264465
# Correct Guesses: 1694/2752 , number of wins: 151/250
# Starting training for Batch: 797 /841 and Epoch: 1
# (2695, 29, 28) (2695, 26) (2695, 26)
# 11/11 [==============================] - 141s 13s/step - loss: 2.4766
# Time taken in seconds to train the batch: 272.4980790615082
# Correct Guesses: 1625/2695 , number of wins: 141/250
# Starting training for Batch: 798 /841 and Epoch: 1
# (2771, 29, 28) (2771, 26) (2771, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4792
# Time taken in seconds to train the batch: 275.5812437534332
# Correct Guesses: 1716/2771 , number of wins: 139/250
# Starting training for Batch: 799 /841 and Epoch: 1
# (2686, 29, 28) (2686, 26) (2686, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.5086
# Time taken in seconds to train the batch: 272.19634771347046
# Correct Guesses: 1580/2686 , number of wins: 131/250
# Starting training for Batch: 800 /841 and Epoch: 1
# (2771, 29, 28) (2771, 26) (2771, 26)
# 11/11 [==============================] - 140s 13s/step - loss: 2.4592
# Time taken in seconds to train the batch: 276.3063552379608
# Correct Guesses: 1679/2771 , number of wins: 137/250
# Starting training for Batch: 801 /841 and Epoch: 1
# (2706, 29, 28) (2706, 26) (2706, 26)
# 11/11 [==============================] - 143s 13s/step - loss: 2.4551
# Time taken in seconds to train the batch: 275.2337739467621
# Correct Guesses: 1643/2706 , number of wins: 139/250
# Starting training for Batch: 802 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 143s 13s/step - loss: 2.4602
# Time taken in seconds to train the batch: 276.9052834510803
# Correct Guesses: 1632/2721 , number of wins: 132/250
# Starting training for Batch: 803 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 143s 13s/step - loss: 2.4734
# Time taken in seconds to train the batch: 276.4570746421814
# Correct Guesses: 1608/2721 , number of wins: 135/250
# Starting training for Batch: 804 /841 and Epoch: 1
# (2736, 29, 28) (2736, 26) (2736, 26)
# 11/11 [==============================] - 145s 13s/step - loss: 2.4561
# Time taken in seconds to train the batch: 279.30915236473083
# Correct Guesses: 1615/2736 , number of wins: 129/250
# Starting training for Batch: 805 /841 and Epoch: 1
# (2717, 29, 28) (2717, 26) (2717, 26)
# 11/11 [==============================] - 144s 13s/step - loss: 2.4580
# Time taken in seconds to train the batch: 277.60272550582886
# Correct Guesses: 1630/2717 , number of wins: 145/250
# Starting training for Batch: 806 /841 and Epoch: 1
# (2780, 29, 28) (2780, 26) (2780, 26)
# 11/11 [==============================] - 142s 13s/step - loss: 2.4369
# Time taken in seconds to train the batch: 279.7761023044586
# Correct Guesses: 1672/2780 , number of wins: 142/250
# Starting training for Batch: 807 /841 and Epoch: 1
# (2679, 29, 28) (2679, 26) (2679, 26)
# 11/11 [==============================] - 142s 13s/step - loss: 2.4427
# Time taken in seconds to train the batch: 274.038964509964
# Correct Guesses: 1645/2679 , number of wins: 151/250
# Starting training for Batch: 808 /841 and Epoch: 1
# (2743, 29, 28) (2743, 26) (2743, 26)
# 11/11 [==============================] - 146s 13s/step - loss: 2.4837
# Time taken in seconds to train the batch: 282.0382719039917
# Correct Guesses: 1671/2743 , number of wins: 145/250
# Starting training for Batch: 809 /841 and Epoch: 1
# (2805, 29, 28) (2805, 26) (2805, 26)
# 11/11 [==============================] - 144s 13s/step - loss: 2.4635
# Time taken in seconds to train the batch: 283.65574407577515
# Correct Guesses: 1611/2805 , number of wins: 126/250
# Starting training for Batch: 810 /841 and Epoch: 1
# (2693, 29, 28) (2693, 26) (2693, 26)
# 11/11 [==============================] - 144s 13s/step - loss: 2.4778
# Time taken in seconds to train the batch: 277.84943747520447
# Correct Guesses: 1626/2693 , number of wins: 138/250
# Starting training for Batch: 811 /841 and Epoch: 1
# (2784, 29, 28) (2784, 26) (2784, 26)
# 11/11 [==============================] - 145s 13s/step - loss: 2.4831
# Time taken in seconds to train the batch: 285.10172390937805
# Correct Guesses: 1681/2784 , number of wins: 134/250
# Starting training for Batch: 812 /841 and Epoch: 1
# (2729, 29, 28) (2729, 26) (2729, 26)
# 11/11 [==============================] - 145s 13s/step - loss: 2.4697
# Time taken in seconds to train the batch: 281.353670835495
# Correct Guesses: 1638/2729 , number of wins: 136/250
# Starting training for Batch: 813 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 145s 13s/step - loss: 2.4625
# Time taken in seconds to train the batch: 280.10424160957336
# Correct Guesses: 1630/2721 , number of wins: 136/250
# Starting training for Batch: 814 /841 and Epoch: 1
# (2722, 29, 28) (2722, 26) (2722, 26)
# 11/11 [==============================] - 147s 13s/step - loss: 2.4692
# Time taken in seconds to train the batch: 282.2649209499359
# Correct Guesses: 1627/2722 , number of wins: 141/250
# Starting training for Batch: 815 /841 and Epoch: 1
# (2732, 29, 28) (2732, 26) (2732, 26)
# 11/11 [==============================] - 149s 14s/step - loss: 2.5093
# Time taken in seconds to train the batch: 284.4224863052368
# Correct Guesses: 1590/2732 , number of wins: 126/250
# Starting training for Batch: 816 /841 and Epoch: 1
# (2659, 29, 28) (2659, 26) (2659, 26)
# 11/11 [==============================] - 143s 13s/step - loss: 2.4761
# Time taken in seconds to train the batch: 275.4150619506836
# Correct Guesses: 1555/2659 , number of wins: 136/250
# Starting training for Batch: 817 /841 and Epoch: 1
# (2731, 29, 28) (2731, 26) (2731, 26)
# 11/11 [==============================] - 148s 13s/step - loss: 2.4957
# Time taken in seconds to train the batch: 284.652108669281
# Correct Guesses: 1596/2731 , number of wins: 132/250
# Starting training for Batch: 818 /841 and Epoch: 1
# (2737, 29, 28) (2737, 26) (2737, 26)
# 11/11 [==============================] - 149s 14s/step - loss: 2.5110
# Time taken in seconds to train the batch: 285.0571255683899
# Correct Guesses: 1602/2737 , number of wins: 124/250
# Starting training for Batch: 819 /841 and Epoch: 1
# (2753, 29, 28) (2753, 26) (2753, 26)
# 11/11 [==============================] - 144s 13s/step - loss: 2.4525
# Time taken in seconds to train the batch: 282.39083433151245
# Correct Guesses: 1631/2753 , number of wins: 135/250
# Starting training for Batch: 820 /841 and Epoch: 1
# (2732, 29, 28) (2732, 26) (2732, 26)
# 11/11 [==============================] - 150s 14s/step - loss: 2.4774
# Time taken in seconds to train the batch: 286.9725675582886
# Correct Guesses: 1631/2732 , number of wins: 129/250
# Starting training for Batch: 821 /841 and Epoch: 1
# (2648, 29, 28) (2648, 26) (2648, 26)
# 11/11 [==============================] - 144s 13s/step - loss: 2.5028
# Time taken in seconds to train the batch: 276.4649066925049
# Correct Guesses: 1567/2648 , number of wins: 128/250
# Starting training for Batch: 822 /841 and Epoch: 1
# (2745, 29, 28) (2745, 26) (2745, 26)
# 11/11 [==============================] - 150s 14s/step - loss: 2.4605
# Time taken in seconds to train the batch: 288.1236484050751
# Correct Guesses: 1653/2745 , number of wins: 137/250
# Starting training for Batch: 823 /841 and Epoch: 1
# (2707, 29, 28) (2707, 26) (2707, 26)
# 11/11 [==============================] - 149s 14s/step - loss: 2.4683
# Time taken in seconds to train the batch: 284.9310348033905
# Correct Guesses: 1571/2707 , number of wins: 138/250
# Starting training for Batch: 824 /841 and Epoch: 1
# (2684, 29, 28) (2684, 26) (2684, 26)
# 11/11 [==============================] - 149s 14s/step - loss: 2.4523
# Time taken in seconds to train the batch: 283.71108055114746
# Correct Guesses: 1582/2684 , number of wins: 136/250
# Starting training for Batch: 825 /841 and Epoch: 1
# (2742, 29, 28) (2742, 26) (2742, 26)
# 11/11 [==============================] - 152s 14s/step - loss: 2.4660
# Time taken in seconds to train the batch: 289.78846502304077
# Correct Guesses: 1651/2742 , number of wins: 138/250
# Starting training for Batch: 826 /841 and Epoch: 1
# (2747, 29, 28) (2747, 26) (2747, 26)
# 11/11 [==============================] - 151s 14s/step - loss: 2.4819
# Time taken in seconds to train the batch: 289.9318425655365
# Correct Guesses: 1624/2747 , number of wins: 127/250
# Starting training for Batch: 827 /841 and Epoch: 1
# (2699, 29, 28) (2699, 26) (2699, 26)
# 11/11 [==============================] - 150s 14s/step - loss: 2.4507
# Time taken in seconds to train the batch: 285.59890246391296
# Correct Guesses: 1643/2699 , number of wins: 150/250
# Starting training for Batch: 828 /841 and Epoch: 1
# (2733, 29, 28) (2733, 26) (2733, 26)
# 11/11 [==============================] - 152s 14s/step - loss: 2.4275
# Time taken in seconds to train the batch: 290.5069258213043
# Correct Guesses: 1667/2733 , number of wins: 148/250
# Starting training for Batch: 829 /841 and Epoch: 1
# (2721, 29, 28) (2721, 26) (2721, 26)
# 11/11 [==============================] - 151s 14s/step - loss: 2.4584
# Time taken in seconds to train the batch: 288.1623709201813
# Correct Guesses: 1662/2721 , number of wins: 147/250
# Starting training for Batch: 830 /841 and Epoch: 1
# (2796, 29, 28) (2796, 26) (2796, 26)
# 11/11 [==============================] - 149s 14s/step - loss: 2.4606
# Time taken in seconds to train the batch: 290.6349604129791
# Correct Guesses: 1683/2796 , number of wins: 140/250
# Starting training for Batch: 831 /841 and Epoch: 1
# (2665, 29, 28) (2665, 26) (2665, 26)
# 11/11 [==============================] - 150s 14s/step - loss: 2.4421
# Time taken in seconds to train the batch: 284.29274892807007
# Correct Guesses: 1566/2665 , number of wins: 138/250
# Starting training for Batch: 832 /841 and Epoch: 1
# (2749, 29, 28) (2749, 26) (2749, 26)
# 11/11 [==============================] - 153s 14s/step - loss: 2.4570
# Time taken in seconds to train the batch: 291.6118874549866
# Correct Guesses: 1676/2749 , number of wins: 140/250
# Starting training for Batch: 833 /841 and Epoch: 1
# (2735, 29, 28) (2735, 26) (2735, 26)
# 11/11 [==============================] - 154s 14s/step - loss: 2.4775
# Time taken in seconds to train the batch: 292.3226013183594
# Correct Guesses: 1594/2735 , number of wins: 121/250
# Starting training for Batch: 834 /841 and Epoch: 1
# (2707, 29, 28) (2707, 26) (2707, 26)
# 11/11 [==============================] - 154s 14s/step - loss: 2.3908
# Time taken in seconds to train the batch: 290.85488843917847
# Correct Guesses: 1680/2707 , number of wins: 154/250
# Starting training for Batch: 835 /841 and Epoch: 1
# (2737, 29, 28) (2737, 26) (2737, 26)
# 11/11 [==============================] - 155s 14s/step - loss: 2.4648
# Time taken in seconds to train the batch: 293.8436141014099
# Correct Guesses: 1669/2737 , number of wins: 141/250
# Starting training for Batch: 836 /841 and Epoch: 1
# (2650, 29, 28) (2650, 26) (2650, 26)
# 11/11 [==============================] - 150s 14s/step - loss: 2.4688
# Time taken in seconds to train the batch: 284.40206599235535
# Correct Guesses: 1609/2650 , number of wins: 153/250
# Starting training for Batch: 837 /841 and Epoch: 1
# (2717, 29, 28) (2717, 26) (2717, 26)
# 11/11 [==============================] - 155s 14s/step - loss: 2.4789
# Time taken in seconds to train the batch: 293.53802704811096
# Correct Guesses: 1618/2717 , number of wins: 130/250
# Starting training for Batch: 838 /841 and Epoch: 1
# (2733, 29, 28) (2733, 26) (2733, 26)
# 11/11 [==============================] - 157s 14s/step - loss: 2.4990
# Time taken in seconds to train the batch: 296.3500282764435
# Correct Guesses: 1634/2733 , number of wins: 131/250
# Starting training for Batch: 839 /841 and Epoch: 1
# (2726, 29, 28) (2726, 26) (2726, 26)
# 11/11 [==============================] - 157s 14s/step - loss: 2.4933
# Time taken in seconds to train the batch: 296.01735854148865
# Correct Guesses: 1609/2726 , number of wins: 135/250
# Starting training for Batch: 840 /841 and Epoch: 1
# (2748, 29, 28) (2748, 26) (2748, 26)
# 11/11 [==============================] - 157s 14s/step - loss: 2.4947
# Time taken in seconds to train the batch: 297.5061399936676
# Correct Guesses: 1615/2748 , number of wins: 127/250
# Completing training for Epoch: 1

# %%
api.trainOnTest()
# Out:
# Starting training for Batch: 1 /70 and Epoch: 1
# (2701, 29, 28) (2701, 26) (2701, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4438
# Time taken in seconds to train the batch: 106.41956114768982
# Correct Guesses: 1993/3260 , number of wins: 178/300
# Starting training for Batch: 2 /70 and Epoch: 1
# (2673, 29, 28) (2673, 26) (2673, 26)
# 11/11 [==============================] - 14s 1s/step - loss: 2.3981
# Time taken in seconds to train the batch: 104.41200757026672
# Correct Guesses: 1627/2673 , number of wins: 156/250
# Starting training for Batch: 3 /70 and Epoch: 1
# (2632, 29, 28) (2632, 26) (2632, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4174
# Time taken in seconds to train the batch: 103.2557463645935
# Correct Guesses: 1640/2632 , number of wins: 161/250
# Starting training for Batch: 4 /70 and Epoch: 1
# (2674, 29, 28) (2674, 26) (2674, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4462
# Time taken in seconds to train the batch: 105.04753184318542
# Correct Guesses: 1628/2674 , number of wins: 156/250
# Starting training for Batch: 5 /70 and Epoch: 1
# (2673, 29, 28) (2673, 26) (2673, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4144
# Time taken in seconds to train the batch: 104.92670321464539
# Correct Guesses: 1651/2673 , number of wins: 160/250
# Starting training for Batch: 6 /70 and Epoch: 1
# (2615, 29, 28) (2615, 26) (2615, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4454
# Time taken in seconds to train the batch: 102.69310760498047
# Correct Guesses: 1573/2615 , number of wins: 143/250
# Starting training for Batch: 7 /70 and Epoch: 1
# (2685, 29, 28) (2685, 26) (2685, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.3865
# Time taken in seconds to train the batch: 105.87689352035522
# Correct Guesses: 1702/2685 , number of wins: 155/250
# Starting training for Batch: 8 /70 and Epoch: 1
# (2683, 29, 28) (2683, 26) (2683, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4450
# Time taken in seconds to train the batch: 105.81574940681458
# Correct Guesses: 1615/2683 , number of wins: 142/250
# Starting training for Batch: 9 /70 and Epoch: 1
# (2659, 29, 28) (2659, 26) (2659, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4536
# Time taken in seconds to train the batch: 104.96094727516174
# Correct Guesses: 1622/2659 , number of wins: 141/250
# Starting training for Batch: 10 /70 and Epoch: 1
# (2656, 29, 28) (2656, 26) (2656, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4251
# Time taken in seconds to train the batch: 104.9288923740387
# Correct Guesses: 1609/2656 , number of wins: 155/250
# Starting training for Batch: 11 /70 and Epoch: 1
# (2660, 29, 28) (2660, 26) (2660, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.3877
# Time taken in seconds to train the batch: 105.2443573474884
# Correct Guesses: 1638/2660 , number of wins: 161/250
# Starting training for Batch: 12 /70 and Epoch: 1
# (2669, 29, 28) (2669, 26) (2669, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4255
# Time taken in seconds to train the batch: 105.60887122154236
# Correct Guesses: 1629/2669 , number of wins: 149/250
# Starting training for Batch: 13 /70 and Epoch: 1
# (2710, 29, 28) (2710, 26) (2710, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4241
# Time taken in seconds to train the batch: 107.46755981445312
# Correct Guesses: 1677/2710 , number of wins: 155/250
# Starting training for Batch: 14 /70 and Epoch: 1
# (2706, 29, 28) (2706, 26) (2706, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4140
# Time taken in seconds to train the batch: 107.18214225769043
# Correct Guesses: 1707/2706 , number of wins: 164/250
# Starting training for Batch: 15 /70 and Epoch: 1
# (2652, 29, 28) (2652, 26) (2652, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4201
# Time taken in seconds to train the batch: 105.81139516830444
# Correct Guesses: 1598/2652 , number of wins: 150/250
# Starting training for Batch: 16 /70 and Epoch: 1
# (2669, 29, 28) (2669, 26) (2669, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4346
# Time taken in seconds to train the batch: 106.38917875289917
# Correct Guesses: 1576/2669 , number of wins: 143/250
# Starting training for Batch: 17 /70 and Epoch: 1
# (2629, 29, 28) (2629, 26) (2629, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4343
# Time taken in seconds to train the batch: 104.84839653968811
# Correct Guesses: 1617/2629 , number of wins: 151/250
# Starting training for Batch: 18 /70 and Epoch: 1
# (2638, 29, 28) (2638, 26) (2638, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4426
# Time taken in seconds to train the batch: 105.73200631141663
# Correct Guesses: 1594/2638 , number of wins: 149/250
# Starting training for Batch: 19 /70 and Epoch: 1
# (2727, 29, 28) (2727, 26) (2727, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4429
# Time taken in seconds to train the batch: 108.72441005706787
# Correct Guesses: 1704/2727 , number of wins: 152/250
# Starting training for Batch: 20 /70 and Epoch: 1
# (2597, 29, 28) (2597, 26) (2597, 26)
# 11/11 [==============================] - 15s 1s/step - loss: 2.4211
# Time taken in seconds to train the batch: 103.5369644165039
# Correct Guesses: 1609/2597 , number of wins: 157/250
# Starting training for Batch: 21 /70 and Epoch: 1
# (2696, 29, 28) (2696, 26) (2696, 26)
# 11/11 [==============================] - 16s 1s/step - loss: 2.4024
# Time taken in seconds to train the batch: 108.11980128288269
# Correct Guesses: 1674/2696 , number of wins: 160/250
# Starting training for Batch: 22 /70 and Epoch: 1
# (2660, 29, 28) (2660, 26) (2660, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4358
# Time taken in seconds to train the batch: 106.76294016838074
# Correct Guesses: 1650/2660 , number of wins: 154/250
# Starting training for Batch: 23 /70 and Epoch: 1
# (2673, 29, 28) (2673, 26) (2673, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.3891
# Time taken in seconds to train the batch: 108.32722640037537
# Correct Guesses: 1693/2673 , number of wins: 168/250
# Starting training for Batch: 24 /70 and Epoch: 1
# (2704, 29, 28) (2704, 26) (2704, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4222
# Time taken in seconds to train the batch: 109.26384115219116
# Correct Guesses: 1676/2704 , number of wins: 155/250
# Starting training for Batch: 25 /70 and Epoch: 1
# (2675, 29, 28) (2675, 26) (2675, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4180
# Time taken in seconds to train the batch: 108.42840600013733
# Correct Guesses: 1672/2675 , number of wins: 155/250
# Starting training for Batch: 26 /70 and Epoch: 1
# (2679, 29, 28) (2679, 26) (2679, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4030
# Time taken in seconds to train the batch: 108.013916015625
# Correct Guesses: 1664/2679 , number of wins: 160/250
# Starting training for Batch: 27 /70 and Epoch: 1
# (2651, 29, 28) (2651, 26) (2651, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4551
# Time taken in seconds to train the batch: 106.91381812095642
# Correct Guesses: 1607/2651 , number of wins: 147/250
# Starting training for Batch: 28 /70 and Epoch: 1
# (2689, 29, 28) (2689, 26) (2689, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4146
# Time taken in seconds to train the batch: 108.75928378105164
# Correct Guesses: 1677/2689 , number of wins: 145/250
# Starting training for Batch: 29 /70 and Epoch: 1
# (2623, 29, 28) (2623, 26) (2623, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.3987
# Time taken in seconds to train the batch: 106.31028509140015
# Correct Guesses: 1635/2623 , number of wins: 155/250
# Starting training for Batch: 30 /70 and Epoch: 1
# (2603, 29, 28) (2603, 26) (2603, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4214
# Time taken in seconds to train the batch: 105.50506567955017
# Correct Guesses: 1605/2603 , number of wins: 154/250
# Starting training for Batch: 31 /70 and Epoch: 1
# (2643, 29, 28) (2643, 26) (2643, 26)
# 11/11 [==============================] - 17s 2s/step - loss: 2.4249
# Time taken in seconds to train the batch: 107.54944610595703
# Correct Guesses: 1621/2643 , number of wins: 149/250
# Starting training for Batch: 32 /70 and Epoch: 1
# (2662, 29, 28) (2662, 26) (2662, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4136
# Time taken in seconds to train the batch: 108.2213487625122
# Correct Guesses: 1708/2662 , number of wins: 168/250
# Starting training for Batch: 33 /70 and Epoch: 1
# (2663, 29, 28) (2663, 26) (2663, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4473
# Time taken in seconds to train the batch: 108.42590665817261
# Correct Guesses: 1614/2663 , number of wins: 145/250
# Starting training for Batch: 34 /70 and Epoch: 1
# (2758, 29, 28) (2758, 26) (2758, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.3778
# Time taken in seconds to train the batch: 111.85562038421631
# Correct Guesses: 1736/2758 , number of wins: 166/250
# Starting training for Batch: 35 /70 and Epoch: 1
# (2655, 29, 28) (2655, 26) (2655, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4059
# Time taken in seconds to train the batch: 108.5220410823822
# Correct Guesses: 1679/2655 , number of wins: 170/250
# Starting training for Batch: 36 /70 and Epoch: 1
# (2663, 29, 28) (2663, 26) (2663, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.3963
# Time taken in seconds to train the batch: 109.03932237625122
# Correct Guesses: 1653/2663 , number of wins: 159/250
# Starting training for Batch: 37 /70 and Epoch: 1
# (2672, 29, 28) (2672, 26) (2672, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.3974
# Time taken in seconds to train the batch: 109.39182353019714
# Correct Guesses: 1669/2672 , number of wins: 156/250
# Starting training for Batch: 38 /70 and Epoch: 1
# (2701, 29, 28) (2701, 26) (2701, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4266
# Time taken in seconds to train the batch: 110.75504422187805
# Correct Guesses: 1666/2701 , number of wins: 149/250
# Starting training for Batch: 39 /70 and Epoch: 1
# (2625, 29, 28) (2625, 26) (2625, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.4579
# Time taken in seconds to train the batch: 107.76410579681396
# Correct Guesses: 1574/2625 , number of wins: 149/250
# Starting training for Batch: 40 /70 and Epoch: 1
# (2649, 29, 28) (2649, 26) (2649, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.3887
# Time taken in seconds to train the batch: 108.95636415481567
# Correct Guesses: 1655/2649 , number of wins: 165/250
# Starting training for Batch: 41 /70 and Epoch: 1
# (2656, 29, 28) (2656, 26) (2656, 26)
# 11/11 [==============================] - 18s 2s/step - loss: 2.3828
# Time taken in seconds to train the batch: 109.3382773399353
# Correct Guesses: 1653/2656 , number of wins: 161/250
# Starting training for Batch: 42 /70 and Epoch: 1
# (2660, 29, 28) (2660, 26) (2660, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.3996
# Time taken in seconds to train the batch: 109.5220000743866
# Correct Guesses: 1660/2660 , number of wins: 156/250
# Starting training for Batch: 43 /70 and Epoch: 1
# (2660, 29, 28) (2660, 26) (2660, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4246
# Time taken in seconds to train the batch: 109.78500437736511
# Correct Guesses: 1652/2660 , number of wins: 162/250
# Starting training for Batch: 44 /70 and Epoch: 1
# (2655, 29, 28) (2655, 26) (2655, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4236
# Time taken in seconds to train the batch: 109.47145056724548
# Correct Guesses: 1618/2655 , number of wins: 150/250
# Starting training for Batch: 45 /70 and Epoch: 1
# (2711, 29, 28) (2711, 26) (2711, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.3871
# Time taken in seconds to train the batch: 112.27215385437012
# Correct Guesses: 1700/2711 , number of wins: 161/250
# Starting training for Batch: 46 /70 and Epoch: 1
# (2689, 29, 28) (2689, 26) (2689, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4222
# Time taken in seconds to train the batch: 111.50638604164124
# Correct Guesses: 1632/2689 , number of wins: 147/250
# Starting training for Batch: 47 /70 and Epoch: 1
# (2656, 29, 28) (2656, 26) (2656, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4310
# Time taken in seconds to train the batch: 110.29875349998474
# Correct Guesses: 1655/2656 , number of wins: 155/250
# Starting training for Batch: 48 /70 and Epoch: 1
# (2640, 29, 28) (2640, 26) (2640, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.3998
# Time taken in seconds to train the batch: 109.60413074493408
# Correct Guesses: 1595/2640 , number of wins: 155/250
# Starting training for Batch: 49 /70 and Epoch: 1
# (2691, 29, 28) (2691, 26) (2691, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.3993
# Time taken in seconds to train the batch: 111.55582594871521
# Correct Guesses: 1644/2691 , number of wins: 153/250
# Starting training for Batch: 50 /70 and Epoch: 1
# (2627, 29, 28) (2627, 26) (2627, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4186
# Time taken in seconds to train the batch: 109.52132987976074
# Correct Guesses: 1673/2627 , number of wins: 165/250
# Starting training for Batch: 51 /70 and Epoch: 1
# (2613, 29, 28) (2613, 26) (2613, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.3890
# Time taken in seconds to train the batch: 108.90204191207886
# Correct Guesses: 1616/2613 , number of wins: 165/250
# Starting training for Batch: 52 /70 and Epoch: 1
# (2646, 29, 28) (2646, 26) (2646, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4382
# Time taken in seconds to train the batch: 110.70455384254456
# Correct Guesses: 1619/2646 , number of wins: 150/250
# Starting training for Batch: 53 /70 and Epoch: 1
# (2670, 29, 28) (2670, 26) (2670, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4118
# Time taken in seconds to train the batch: 111.68084764480591
# Correct Guesses: 1644/2670 , number of wins: 156/250
# Starting training for Batch: 54 /70 and Epoch: 1
# (2622, 29, 28) (2622, 26) (2622, 26)
# 11/11 [==============================] - 19s 2s/step - loss: 2.4317
# Time taken in seconds to train the batch: 109.72541761398315
# Correct Guesses: 1598/2622 , number of wins: 140/250
# Starting training for Batch: 55 /70 and Epoch: 1
# (2689, 29, 28) (2689, 26) (2689, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4215
# Time taken in seconds to train the batch: 112.66083765029907
# Correct Guesses: 1687/2689 , number of wins: 159/250
# Starting training for Batch: 56 /70 and Epoch: 1
# (2690, 29, 28) (2690, 26) (2690, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4437
# Time taken in seconds to train the batch: 112.84498882293701
# Correct Guesses: 1614/2690 , number of wins: 145/250
# Starting training for Batch: 57 /70 and Epoch: 1
# (2708, 29, 28) (2708, 26) (2708, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4128
# Time taken in seconds to train the batch: 114.01090335845947
# Correct Guesses: 1711/2708 , number of wins: 159/250
# Starting training for Batch: 58 /70 and Epoch: 1
# (2661, 29, 28) (2661, 26) (2661, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4038
# Time taken in seconds to train the batch: 111.88669180870056
# Correct Guesses: 1654/2661 , number of wins: 159/250
# Starting training for Batch: 59 /70 and Epoch: 1
# (2652, 29, 28) (2652, 26) (2652, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4572
# Time taken in seconds to train the batch: 112.04558539390564
# Correct Guesses: 1593/2652 , number of wins: 140/250
# Starting training for Batch: 60 /70 and Epoch: 1
# (2639, 29, 28) (2639, 26) (2639, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4053
# Time taken in seconds to train the batch: 111.63717865943909
# Correct Guesses: 1663/2639 , number of wins: 160/250
# Starting training for Batch: 61 /70 and Epoch: 1
# (2658, 29, 28) (2658, 26) (2658, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4218
# Time taken in seconds to train the batch: 112.5940294265747
# Correct Guesses: 1625/2658 , number of wins: 160/250
# Starting training for Batch: 62 /70 and Epoch: 1
# (2632, 29, 28) (2632, 26) (2632, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4068
# Time taken in seconds to train the batch: 111.80752801895142
# Correct Guesses: 1663/2632 , number of wins: 170/250
# Starting training for Batch: 63 /70 and Epoch: 1
# (2691, 29, 28) (2691, 26) (2691, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4374
# Time taken in seconds to train the batch: 114.26749086380005
# Correct Guesses: 1638/2691 , number of wins: 145/250
# Starting training for Batch: 64 /70 and Epoch: 1
# (2674, 29, 28) (2674, 26) (2674, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4537
# Time taken in seconds to train the batch: 113.38641715049744
# Correct Guesses: 1666/2674 , number of wins: 155/250
# Starting training for Batch: 65 /70 and Epoch: 1
# (2609, 29, 28) (2609, 26) (2609, 26)
# 11/11 [==============================] - 20s 2s/step - loss: 2.4627
# Time taken in seconds to train the batch: 110.39748811721802
# Correct Guesses: 1576/2609 , number of wins: 147/250
# Starting training for Batch: 66 /70 and Epoch: 1
# (2703, 29, 28) (2703, 26) (2703, 26)
# 11/11 [==============================] - 22s 2s/step - loss: 2.4045
# Time taken in seconds to train the batch: 115.17104649543762
# Correct Guesses: 1664/2703 , number of wins: 154/250
# Starting training for Batch: 67 /70 and Epoch: 1
# (2609, 29, 28) (2609, 26) (2609, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.3849
# Time taken in seconds to train the batch: 110.80566048622131
# Correct Guesses: 1674/2609 , number of wins: 171/250
# Starting training for Batch: 68 /70 and Epoch: 1
# (2675, 29, 28) (2675, 26) (2675, 26)
# 11/11 [==============================] - 21s 2s/step - loss: 2.4389
# Time taken in seconds to train the batch: 113.958251953125
# Correct Guesses: 1670/2675 , number of wins: 161/250
# Starting training for Batch: 69 /70 and Epoch: 1
# (2653, 29, 28) (2653, 26) (2653, 26)
# 11/11 [==============================] - 22s 2s/step - loss: 2.4126
# Time taken in seconds to train the batch: 113.47185111045837
# Correct Guesses: 1642/2653 , number of wins: 153/250
# Completing training for Epoch: 1

# %%
api.model.save("model3_3.h5")

# %% [markdown]
# # Final Submission

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        self.model=load_model("model3_3.h5",custom_objects={"SeqSelfAttention":SeqSelfAttention})
        self.maxLen = 29
        self.encoderDict=dict(zip(ascii_lowercase, range(26)))
        self.encoderDict["_"]=26 #missing letters
        self.encoderDict["."] =27 #padding
        self.decoderDict=dict(zip(range(26),ascii_lowercase))
        self.current_dictionary = []
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link
        
    def encode(self,word):
        
        if(len(word)<self.maxLen):word=word+"".join(["."]*(self.maxLen-len(word)))
        encoded=np.zeros((1,self.maxLen,28))
        for i in range(self.maxLen):
            if(word[i]=="." or word[i] in self.guessed_letters):
                    encoded[0,i,self.encoderDict[word[i]]]=1
            else:encoded[0,i,26]=1
        return encoded    
    def guess(self, word):
        word = word[::2]
        i1=self.encode(word)
        i2=np.zeros((1,26))
        for x in self.guessed_letters:
            i2[0,self.encoderDict[x]]=1
        guesses = np.flip(np.argsort(self.model.predict([i1,i2],verbose=None)))[0]
        guess_letter='!'
        for i in guesses.tolist():
            guess = self.decoderDict[i]
            if guess not in self.guessed_letters:
                guess_letter=guess
                break
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break 
        return guess_letter            
    #             print(word,guess,self.remainingLetters)
    #             print()
    #             print(output)
    #             print()
    def guess2(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_",".")
        
        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter
    def guess3(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        
                
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
                
            # if dictionary word is a possible match then add it to the current dictionary
            if self.match(dict_word,word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        guess_letter = '!'
        d={}
        for x in range(len(word)):
            totalProb = {}
            if word[x]=="_":
                sortedCount=collections.Counter("".join([a[x] for a in new_dictionary]))
                total = sum(sortedCount.values())
                sortedCount = {key:sortedCount[key]/total for key in sortedCount.keys()}
#                 sortedCount = sorted(sortedCount.items(), key=lambda x:-x[1])
                #print(sortedCount)
                d[x]=sortedCount
                totalProb = {x: totalProb.get(x, 0) + sortedCount.get(x, 0)
                    for x in set(totalProb).union(sortedCount)}
            d[-1]=sorted(totalProb.items(), key=lambda x:-x[1])   
        maxProbalities = {}
        maxProb = 0 
        if(len(d)>0):
            if(-1 in d):
                for letter,prob in d[-1]:
                    if letter not in self.guessed_letters:
                        if maxProb<prob:
                            maxProb = prob
                            guess_letter = letter
                            break
                
#             for a in d.keys():
#                 for letter,prob in d[a]:
#                     if letter not in self.guessed_letters:
#                         if maxProb<prob:
#                             maxProb = prob
#                             guess_letter = letter
#                             break
                        
#         # count occurrence of all characters in possible word matches
#         full_dict_string = "".join(new_dictionary)
        
#         c = collections.Counter(full_dict_string)
#         sorted_letter_count = c.most_common()                   
        
#         guess_letter = '!'
        
#         # return most frequently occurring letter in all possible words that hasn't been guessed yet
#         for letter,instance_count in sorted_letter_count:
#             if letter not in self.guessed_letters:
#                 guess_letter = letter
#                 break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter
    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
    
    def match(self,word1,word2):
        word1=list(word1)
        word2=list(word2)
        if(len(word1)==len(word2)):
            for x in range(len(word1)):
                if word2[x]!="_" and word2[x]!=word1[x]:
                    return False
            return True
        else: return False                 
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="c66cf58acd4576d68a22e165b1f254", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
api.start_game(practice=1,verbose=True)
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs
print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Successfully start a new game! Game ID: c91202669577. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ _ _ _ _ _ _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ _ _ _ _ _ _ r i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ t _ _ _ _ _ r i _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e i _ _ t _ e _ _ _ r i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e i _ _ t _ e _ _ _ r i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e i _ _ t _ e a _ _ r i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e i _ _ t _ e a _ _ r i n _ '}
# Guessing letter: h
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e i _ h t _ e a _ _ r i n _ '}
# Guessing letter: g
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e i g h t _ e a _ _ r i n g '}
# Guessing letter: l
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e i g h t _ e a _ _ r i n g '}
# Guessing letter: b
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e i g h t _ e a _ _ r i n g '}
# Guessing letter: s
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e i g h t _ e a s _ r i n g '}
# Guessing letter: u
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e i g h t _ e a s u r i n g '}
# Guessing letter: d
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e i g h t _ e a s u r i n g '}
# Guessing letter: f
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e i g h t _ e a s u r i n g '}
# Guessing letter: m
# Sever response: {'game_id': 'c91202669577', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e i g h t m e a s u r i n g '}
# Guessing letter: w
# Sever response: {'game_id': 'c91202669577', 'status': 'success', 'tries_remains': 1, 'word': 'w e i g h t m e a s u r i n g '}
# Successfully finished game: c91202669577
# run 14602 practice games out of an allotted 100,000. practice success rate so far = 0.481

# %%
for x in range(600):
    api.start_game(practice=1,verbose=False)
    if(x%50==0):
        print("Played "+str(x)+" games")
    time.sleep(0.5)
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs
print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Played 0 games
# Played 50 games
# Played 100 games
# Played 150 games
# Played 200 games
# Played 250 games
# Played 300 games
# Played 350 games
# Played 400 games
# Played 450 games
# Played 500 games
# Played 550 games
# run 14600 practice games out of an allotted 100,000. practice success rate so far = 0.481

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Playing  1  th game
# Playing  2  th game
# Playing  3  th game
# Playing  4  th game
# Playing  5  th game
# Playing  6  th game
# Playing  7  th game
# Playing  8  th game
# Playing  9  th game
# Playing  10  th game
# Playing  11  th game
# Playing  12  th game
# Playing  13  th game
# Playing  14  th game
# Playing  15  th game
# Playing  16  th game
# Playing  17  th game
# Playing  18  th game
# Playing  19  th game
# Playing  20  th game
# Playing  21  th game
# Playing  22  th game
# Playing  23  th game
# Playing  24  th game
# Playing  25  th game
# Playing  26  th game
# Playing  27  th game
# Playing  28  th game
# Playing  29  th game
# Playing  30  th game
# Playing  31  th game
# Playing  32  th game
# Playing  33  th game
# Playing  34  th game
# Playing  35  th game
# Playing  36  th game
# Playing  37  th game
# Playing  38  th game
# Playing  39  th game
# Playing  40  th game
# Playing  41  th game
# Playing  42  th game
# Playing  43  th game
# Playing  44  th game
# Playing  45  th game
# Playing  46  th game
# Playing  47  th game
# Playing  48  th game
# Playing  49  th game
# Playing  50  th game
# Playing  51  th game
# Playing  52  th game
# Playing  53  th game
# Playing  54  th game
# Playing  55  th game
# Playing  56  th game
# Playing  57  th game
# Playing  58  th game
# Playing  59  th game
# Playing  60  th game
# Playing  61  th game
# Playing  62  th game
# Playing  63  th game
# Playing  64  th game
# Playing  65  th game
# Playing  66  th game
# Playing  67  th game
# Playing  68  th game
# Playing  69  th game
# Playing  70  th game
# Playing  71  th game
# Playing  72  th game
# Playing  73  th game
# Playing  74  th game
# Playing  75  th game
# Playing  76  th game
# Playing  77  th game
# Playing  78  th game
# Playing  79  th game
# Playing  80  th game
# Playing  81  th game
# Playing  82  th game
# Playing  83  th game
# Playing  84  th game
# Playing  85  th game
# Playing  86  th game
# Playing  87  th game
# Playing  88  th game
# Playing  89  th game
# Playing  90  th game
# Playing  91  th game
# Playing  92  th game
# Playing  93  th game
# Playing  94  th game
# Playing  95  th game
# Playing  96  th game
# Playing  97  th game
# Playing  98  th game
# Playing  99  th game
# Playing  100  th game
# Playing  101  th game
# Playing  102  th game
# Playing  103  th game
# Playing  104  th game
# Playing  105  th game
# Playing  106  th game
# Playing  107  th game
# Playing  108  th game
# Playing  109  th game
# Playing  110  th game
# Playing  111  th game
# Playing  112  th game
# Playing  113  th game
# Playing  114  th game
# Playing  115  th game
# Playing  116  th game
# Playing  117  th game
# Playing  118  th game
# Playing  119  th game
# Playing  120  th game
# Playing  121  th game
# Playing  122  th game
# Playing  123  th game
# Playing  124  th game
# Playing  125  th game
# Playing  126  th game
# Playing  127  th game
# Playing  128  th game
# Playing  129  th game
# Playing  130  th game
# Playing  131  th game
# Playing  132  th game
# Playing  133  th game
# Playing  134  th game
# Playing  135  th game
# Playing  136  th game
# Playing  137  th game
# Playing  138  th game
# Playing  139  th game
# Playing  140  th game
# Playing  141  th game
# Playing  142  th game
# Playing  143  th game
# Playing  144  th game
# Playing  145  th game
# Playing  146  th game
# Playing  147  th game
# Playing  148  th game
# Playing  149  th game
# Playing  150  th game
# Playing  151  th game
# Playing  152  th game
# Playing  153  th game
# Playing  154  th game
# Playing  155  th game
# Playing  156  th game
# Playing  157  th game
# Playing  158  th game
# Playing  159  th game
# Playing  160  th game
# Playing  161  th game
# Playing  162  th game
# Playing  163  th game
# Playing  164  th game
# Playing  165  th game
# Playing  166  th game
# Playing  167  th game
# Playing  168  th game
# Playing  169  th game
# Playing  170  th game
# Playing  171  th game
# Playing  172  th game
# Playing  173  th game
# Playing  174  th game
# Playing  175  th game
# Playing  176  th game
# Playing  177  th game
# Playing  178  th game
# Playing  179  th game
# Playing  180  th game
# Playing  181  th game
# Playing  182  th game
# Playing  183  th game
# Playing  184  th game
# Playing  185  th game
# Playing  186  th game
# Playing  187  th game
# Playing  188  th game
# Playing  189  th game
# Playing  190  th game
# Playing  191  th game
# Playing  192  th game
# Playing  193  th game
# Playing  194  th game
# Playing  195  th game
# Playing  196  th game
# Playing  197  th game
# Playing  198  th game
# Playing  199  th game
# Playing  200  th game
# Playing  201  th game
# Playing  202  th game
# Playing  203  th game
# Playing  204  th game
# Playing  205  th game
# Playing  206  th game
# Playing  207  th game
# Playing  208  th game
# Playing  209  th game
# Playing  210  th game
# Playing  211  th game
# Playing  212  th game
# Playing  213  th game
# Playing  214  th game
# Playing  215  th game
# Playing  216  th game
# Playing  217  th game
# Playing  218  th game
# Playing  219  th game
# Playing  220  th game
# Playing  221  th game
# Playing  222  th game
# Playing  223  th game
# Playing  224  th game
# Playing  225  th game
# Playing  226  th game
# Playing  227  th game
# Playing  228  th game
# Playing  229  th game
# Playing  230  th game
# Playing  231  th game
# Playing  232  th game
# Playing  233  th game
# Playing  234  th game
# Playing  235  th game
# Playing  236  th game
# Playing  237  th game
# Playing  238  th game
# Playing  239  th game
# Playing  240  th game
# Playing  241  th game
# Playing  242  th game
# Playing  243  th game
# Playing  244  th game
# Playing  245  th game
# Playing  246  th game
# Playing  247  th game
# Playing  248  th game
# Playing  249  th game
# Playing  250  th game
# Playing  251  th game
# Playing  252  th game
# Playing  253  th game
# Playing  254  th game
# Playing  255  th game
# Playing  256  th game
# Playing  257  th game
# Playing  258  th game
# Playing  259  th game
# Playing  260  th game
# Playing  261  th game
# Playing  262  th game
# Playing  263  th game
# Playing  264  th game
# Playing  265  th game
# Playing  266  th game
# Playing  267  th game
# Playing  268  th game
# Playing  269  th game
# Playing  270  th game
# Playing  271  th game
# Playing  272  th game
# Playing  273  th game
# Playing  274  th game
# Playing  275  th game
# Playing  276  th game
# Playing  277  th game
# Playing  278  th game
# Playing  279  th game
# Playing  280  th game
# Playing  281  th game
# Playing  282  th game
# Playing  283  th game
# Playing  284  th game
# Playing  285  th game
# Playing  286  th game
# Playing  287  th game
# Playing  288  th game
# Playing  289  th game
# Playing  290  th game
# Playing  291  th game
# Playing  292  th game
# Playing  293  th game
# Playing  294  th game
# Playing  295  th game
# Playing  296  th game
# Playing  297  th game
# Playing  298  th game
# Playing  299  th game
# Playing  300  th game
# Playing  301  th game
# Playing  302  th game
# Playing  303  th game
# Playing  304  th game
# Playing  305  th game
# Playing  306  th game
# Playing  307  th game
# Playing  308  th game
# Playing  309  th game
# Playing  310  th game
# Playing  311  th game
# Playing  312  th game
# Playing  313  th game
# Playing  314  th game
# Playing  315  th game
# Playing  316  th game
# Playing  317  th game
# Playing  318  th game
# Playing  319  th game
# Playing  320  th game
# Playing  321  th game
# Playing  322  th game
# Playing  323  th game
# Playing  324  th game
# Playing  325  th game
# Playing  326  th game
# Playing  327  th game
# Playing  328  th game
# Playing  329  th game
# Playing  330  th game
# Playing  331  th game
# Playing  332  th game
# Playing  333  th game
# Playing  334  th game
# Playing  335  th game
# Playing  336  th game
# Playing  337  th game
# Playing  338  th game
# Playing  339  th game
# Playing  340  th game
# Playing  341  th game
# Playing  342  th game
# Playing  343  th game
# Playing  344  th game
# Playing  345  th game
# Playing  346  th game
# Playing  347  th game
# Playing  348  th game
# Playing  349  th game
# Playing  350  th game
# Playing  351  th game
# Playing  352  th game
# Playing  353  th game
# Playing  354  th game
# Playing  355  th game
# Playing  356  th game
# Playing  357  th game
# Playing  358  th game
# Playing  359  th game
# Playing  360  th game
# Playing  361  th game
# Playing  362  th game
# Playing  363  th game
# Playing  364  th game
# Playing  365  th game
# Playing  366  th game
# Playing  367  th game
# Playing  368  th game
# Playing  369  th game
# Playing  370  th game
# Playing  371  th game
# Playing  372  th game
# Playing  373  th game
# Playing  374  th game
# Playing  375  th game
# Playing  376  th game
# Playing  377  th game
# Playing  378  th game
# Playing  379  th game
# Playing  380  th game
# Playing  381  th game
# Playing  382  th game
# Playing  383  th game
# Playing  384  th game
# Playing  385  th game
# Playing  386  th game
# Playing  387  th game
# Playing  388  th game
# Playing  389  th game
# Playing  390  th game
# Playing  391  th game
# Playing  392  th game
# Playing  393  th game
# Playing  394  th game
# Playing  395  th game
# Playing  396  th game
# Playing  397  th game
# Playing  398  th game
# Playing  399  th game
# Playing  400  th game
# Playing  401  th game
# Playing  402  th game
# Playing  403  th game
# Playing  404  th game
# Playing  405  th game
# Playing  406  th game
# Playing  407  th game
# Playing  408  th game
# Playing  409  th game
# Playing  410  th game
# Playing  411  th game
# Playing  412  th game
# Playing  413  th game
# Playing  414  th game
# Playing  415  th game
# Playing  416  th game
# Playing  417  th game
# Playing  418  th game
# Playing  419  th game
# Playing  420  th game
# Playing  421  th game
# Playing  422  th game
# Playing  423  th game
# Playing  424  th game
# Playing  425  th game
# Playing  426  th game
# Playing  427  th game
# Playing  428  th game
# Playing  429  th game
# Playing  430  th game
# Playing  431  th game
# Playing  432  th game
# Playing  433  th game
# Playing  434  th game
# Playing  435  th game
# Playing  436  th game
# Playing  437  th game
# Playing  438  th game
# Playing  439  th game
# Playing  440  th game
# Playing  441  th game
# Playing  442  th game
# Playing  443  th game
# Playing  444  th game
# Playing  445  th game
# Playing  446  th game
# Playing  447  th game
# Playing  448  th game
# Playing  449  th game
# Playing  450  th game
# Playing  451  th game
# Playing  452  th game
# Playing  453  th game
# Playing  454  th game
# Playing  455  th game
# Playing  456  th game
# Playing  457  th game
# Playing  458  th game
# Playing  459  th game
# Playing  460  th game
# Playing  461  th game
# Playing  462  th game
# Playing  463  th game
# Playing  464  th game
# Playing  465  th game
# Playing  466  th game
# Playing  467  th game
# Playing  468  th game
# Playing  469  th game
# Playing  470  th game
# Playing  471  th game
# Playing  472  th game
# Playing  473  th game
# Playing  474  th game
# Playing  475  th game
# Playing  476  th game
# Playing  477  th game
# Playing  478  th game
# Playing  479  th game
# Playing  480  th game
# Playing  481  th game
# Playing  482  th game
# Playing  483  th game
# Playing  484  th game
# Playing  485  th game
# Playing  486  th game
# Playing  487  th game
# Playing  488  th game
# Playing  489  th game
# Playing  490  th game
# Playing  491  th game
# Playing  492  th game
# Playing  493  th game
# Playing  494  th game
# Playing  495  th game
# Playing  496  th game
# Playing  497  th game
# Playing  498  th game
# Playing  499  th game
# Playing  500  th game
# Playing  501  th game
# Playing  502  th game
# Playing  503  th game
# Playing  504  th game
# Playing  505  th game
# Playing  506  th game
# Playing  507  th game
# Playing  508  th game
# Playing  509  th game
# Playing  510  th game
# Playing  511  th game
# Playing  512  th game
# Playing  513  th game
# Playing  514  th game
# Playing  515  th game
# Playing  516  th game
# Playing  517  th game
# Playing  518  th game
# Playing  519  th game
# Playing  520  th game
# Playing  521  th game
# Playing  522  th game
# Playing  523  th game
# Playing  524  th game
# Playing  525  th game
# Playing  526  th game
# Playing  527  th game
# Playing  528  th game
# Playing  529  th game
# Playing  530  th game
# Playing  531  th game
# Playing  532  th game
# Playing  533  th game
# Playing  534  th game
# Playing  535  th game
# Playing  536  th game
# Playing  537  th game
# Playing  538  th game
# Playing  539  th game
# Playing  540  th game
# Playing  541  th game
# Playing  542  th game
# Playing  543  th game
# Playing  544  th game
# Playing  545  th game
# Playing  546  th game
# Playing  547  th game
# Playing  548  th game
# Playing  549  th game
# Playing  550  th game
# Playing  551  th game
# Playing  552  th game
# Playing  553  th game
# Playing  554  th game
# Playing  555  th game
# Playing  556  th game
# Playing  557  th game
# Playing  558  th game
# Playing  559  th game
# Playing  560  th game
# Playing  561  th game
# Playing  562  th game
# Playing  563  th game
# Playing  564  th game
# Playing  565  th game
# Playing  566  th game
# Playing  567  th game
# Playing  568  th game
# Playing  569  th game
# Playing  570  th game
# Playing  571  th game
# Playing  572  th game
# Playing  573  th game
# Playing  574  th game
# Playing  575  th game
# Playing  576  th game
# Playing  577  th game
# Playing  578  th game
# Playing  579  th game
# Playing  580  th game
# Playing  581  th game
# Playing  582  th game
# Playing  583  th game
# Playing  584  th game
# Playing  585  th game
# Playing  586  th game
# Playing  587  th game
# Playing  588  th game
# Playing  589  th game
# Playing  590  th game
# Playing  591  th game
# Playing  592  th game
# Playing  593  th game
# Playing  594  th game
# Playing  595  th game
# Playing  596  th game
# Playing  597  th game
# Playing  598  th game
# Playing  599  th game
# Playing  600  th game
# Playing  601  th game
# Playing  602  th game
# Playing  603  th game
# Playing  604  th game
# Playing  605  th game
# Playing  606  th game
# Playing  607  th game
# Playing  608  th game
# Playing  609  th game
# Playing  610  th game
# Playing  611  th game
# Playing  612  th game
# Playing  613  th game
# Playing  614  th game
# Playing  615  th game
# Playing  616  th game
# Playing  617  th game
# Playing  618  th game
# Playing  619  th game
# Playing  620  th game
# Playing  621  th game
# Playing  622  th game
# Playing  623  th game
# Playing  624  th game
# Playing  625  th game
# Playing  626  th game
# Playing  627  th game
# Playing  628  th game
# Playing  629  th game
# Playing  630  th game
# Playing  631  th game
# Playing  632  th game
# Playing  633  th game
# Playing  634  th game
# Playing  635  th game
# Playing  636  th game
# Playing  637  th game
# Playing  638  th game
# Playing  639  th game
# Playing  640  th game
# Playing  641  th game
# Playing  642  th game
# Playing  643  th game
# Playing  644  th game
# Playing  645  th game
# Playing  646  th game
# Playing  647  th game
# Playing  648  th game
# Playing  649  th game
# Playing  650  th game
# Playing  651  th game
# Playing  652  th game
# Playing  653  th game
# Playing  654  th game
# Playing  655  th game
# Playing  656  th game
# Playing  657  th game
# Playing  658  th game
# Playing  659  th game
# Playing  660  th game
# Playing  661  th game
# Playing  662  th game
# Playing  663  th game
# Playing  664  th game
# Playing  665  th game
# Playing  666  th game
# Playing  667  th game
# Playing  668  th game
# Playing  669  th game
# Playing  670  th game
# Playing  671  th game
# Playing  672  th game
# Playing  673  th game
# Playing  674  th game
# Playing  675  th game
# Playing  676  th game
# Playing  677  th game
# Playing  678  th game
# Playing  679  th game
# Playing  680  th game
# Playing  681  th game
# Playing  682  th game
# Playing  683  th game
# Playing  684  th game
# Playing  685  th game
# Playing  686  th game
# Playing  687  th game
# Playing  688  th game
# Playing  689  th game
# Playing  690  th game
# Playing  691  th game
# Playing  692  th game
# Playing  693  th game
# Playing  694  th game
# Playing  695  th game
# Playing  696  th game
# Playing  697  th game
# Playing  698  th game
# Playing  699  th game
# Playing  700  th game
# Playing  701  th game
# Playing  702  th game
# Playing  703  th game
# Playing  704  th game
# Playing  705  th game
# Playing  706  th game
# Playing  707  th game
# Playing  708  th game
# Playing  709  th game
# Playing  710  th game
# Playing  711  th game
# Playing  712  th game
# Playing  713  th game
# Playing  714  th game
# Playing  715  th game
# Playing  716  th game
# Playing  717  th game
# Playing  718  th game
# Playing  719  th game
# Playing  720  th game
# Playing  721  th game
# Playing  722  th game
# Playing  723  th game
# Playing  724  th game
# Playing  725  th game
# Playing  726  th game
# Playing  727  th game
# Playing  728  th game
# Playing  729  th game
# Playing  730  th game
# Playing  731  th game
# Playing  732  th game
# Playing  733  th game
# Playing  734  th game
# Playing  735  th game
# Playing  736  th game
# Playing  737  th game
# Playing  738  th game
# Playing  739  th game
# Playing  740  th game
# Playing  741  th game
# Playing  742  th game
# Playing  743  th game
# Playing  744  th game
# Playing  745  th game
# Playing  746  th game
# Playing  747  th game
# Playing  748  th game
# Playing  749  th game
# Playing  750  th game
# Playing  751  th game
# Playing  752  th game
# Playing  753  th game
# Playing  754  th game
# Playing  755  th game
# Playing  756  th game
# Playing  757  th game
# Playing  758  th game
# Playing  759  th game
# Playing  760  th game
# Playing  761  th game
# Playing  762  th game
# Playing  763  th game
# Playing  764  th game
# Playing  765  th game
# Playing  766  th game
# Playing  767  th game
# Playing  768  th game
# Playing  769  th game
# Playing  770  th game
# Playing  771  th game
# Playing  772  th game
# Playing  773  th game
# Playing  774  th game
# Playing  775  th game
# Playing  776  th game
# Playing  777  th game
# Playing  778  th game
# Playing  779  th game
# Playing  780  th game
# Playing  781  th game
# Playing  782  th game
# Playing  783  th game
# Playing  784  th game
# Playing  785  th game
# Playing  786  th game
# Playing  787  th game
# Playing  788  th game
# Playing  789  th game
# Playing  790  th game
# Playing  791  th game
# Playing  792  th game
# Playing  793  th game
# Playing  794  th game
# Playing  795  th game
# Playing  796  th game
# Playing  797  th game
# Playing  798  th game
# Playing  799  th game
# Playing  800  th game
# Playing  801  th game
# Playing  802  th game
# Playing  803  th game
# Playing  804  th game
# Playing  805  th game
# Playing  806  th game
# Playing  807  th game
# Playing  808  th game
# Playing  809  th game
# Playing  810  th game
# Playing  811  th game
# Playing  812  th game
# Playing  813  th game
# Playing  814  th game
# Playing  815  th game
# Playing  816  th game
# Playing  817  th game
# Playing  818  th game
# Playing  819  th game
# Playing  820  th game
# Playing  821  th game
# Playing  822  th game
# Playing  823  th game
# Playing  824  th game
# Playing  825  th game
# Playing  826  th game
# Playing  827  th game
# Playing  828  th game
# Playing  829  th game
# Playing  830  th game
# Playing  831  th game
# Playing  832  th game
# Playing  833  th game
# Playing  834  th game
# Playing  835  th game
# Playing  836  th game
# Playing  837  th game
# Playing  838  th game
# Playing  839  th game
# Playing  840  th game
# Playing  841  th game
# Playing  842  th game
# Playing  843  th game
# Playing  844  th game
# Playing  845  th game
# Playing  846  th game
# Playing  847  th game
# Playing  848  th game
# Playing  849  th game
# Playing  850  th game
# Playing  851  th game
# Playing  852  th game
# Playing  853  th game
# Playing  854  th game
# Playing  855  th game
# Playing  856  th game
# Playing  857  th game
# Playing  858  th game
# Playing  859  th game
# Playing  860  th game
# Playing  861  th game
# Playing  862  th game
# Playing  863  th game
# Playing  864  th game
# Playing  865  th game
# Playing  866  th game
# Playing  867  th game
# Playing  868  th game
# Playing  869  th game
# Playing  870  th game
# Playing  871  th game
# Playing  872  th game
# Playing  873  th game
# Playing  874  th game
# Playing  875  th game
# Playing  876  th game
# Playing  877  th game
# Playing  878  th game
# Playing  879  th game
# Playing  880  th game
# Playing  881  th game
# Playing  882  th game
# Playing  883  th game
# Playing  884  th game
# Playing  885  th game
# Playing  886  th game
# Playing  887  th game
# Playing  888  th game
# Playing  889  th game
# Playing  890  th game
# Playing  891  th game
# Playing  892  th game
# Playing  893  th game
# Playing  894  th game
# Playing  895  th game
# Playing  896  th game
# Playing  897  th game
# Playing  898  th game
# Playing  899  th game
# Playing  900  th game
# Playing  901  th game
# Playing  902  th game
# Playing  903  th game
# Playing  904  th game
# Playing  905  th game
# Playing  906  th game
# Playing  907  th game
# Playing  908  th game
# Playing  909  th game
# Playing  910  th game
# Playing  911  th game
# Playing  912  th game
# Playing  913  th game
# Playing  914  th game
# Playing  915  th game
# Playing  916  th game
# Playing  917  th game
# Playing  918  th game
# Playing  919  th game
# Playing  920  th game
# Playing  921  th game
# Playing  922  th game
# Playing  923  th game
# Playing  924  th game
# Playing  925  th game
# Playing  926  th game
# Playing  927  th game
# Playing  928  th game
# Playing  929  th game
# Playing  930  th game
# Playing  931  th game
# Playing  932  th game
# Playing  933  th game
# Playing  934  th game
# Playing  935  th game
# Playing  936  th game
# Playing  937  th game
# Playing  938  th game
# Playing  939  th game
# Playing  940  th game
# Playing  941  th game
# Playing  942  th game
# Playing  943  th game
# Playing  944  th game
# Playing  945  th game
# Playing  946  th game
# Playing  947  th game
# Playing  948  th game
# Playing  949  th game
# Playing  950  th game
# Playing  951  th game
# Playing  952  th game
# Playing  953  th game
# Playing  954  th game
# Playing  955  th game
# Playing  956  th game
# Playing  957  th game
# Playing  958  th game
# Playing  959  th game
# Playing  960  th game
# Playing  961  th game
# Playing  962  th game
# Playing  963  th game
# Playing  964  th game
# Playing  965  th game
# Playing  966  th game
# Playing  967  th game
# Playing  968  th game
# Playing  969  th game
# Playing  970  th game
# Playing  971  th game
# Playing  972  th game
# Playing  973  th game
# Playing  974  th game
# Playing  975  th game
# Playing  976  th game
# Playing  977  th game
# Playing  978  th game
# Playing  979  th game
# Playing  980  th game
# Playing  981  th game
# Playing  982  th game
# Playing  983  th game
# Playing  984  th game
# Playing  985  th game
# Playing  986  th game
# Playing  987  th game
# Playing  988  th game
# Playing  989  th game
# Playing  990  th game
# Playing  991  th game
# Playing  992  th game
# Playing  993  th game
# Playing  994  th game
# Playing  995  th game
# Playing  996  th game
# Playing  997  th game
# Playing  998  th game
# Playing  999  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=False)
#       6 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       7 time.sleep(0.5)
#
# Input In [2], in HangmanAPI.start_game(self, practice, verbose)
#     225 self.guessed_letters = []
#     226 self.current_dictionary = self.full_dictionary
# --> 228 response = self.request("/new_game", {"practice":practice})
#     229 if response.get('status')=="approved":
#     230     game_id = response.get('game_id')
#
# Input In [2], in HangmanAPI.request(self, path, args, post_args, method)
#     327     raise HangmanAPIError('Maintype was not text, or querystring')
#     329 if result and isinstance(result, dict) and result.get("error"):
# --> 330     raise HangmanAPIError(result)
#     331 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# overall success rate = 0.517

# %%
api.my_status()
# Out:
# [14602, 1000, 517, 7021]
